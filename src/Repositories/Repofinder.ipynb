# %%
import os
import re
import time
import requests
from dotenv import load_dotenv

# Load environment variables
def load_env():
    load_dotenv()

# Extract API Key from .env file
def get_api_key():
    load_env()
    return os.getenv("MARKET_CAP_API_KEY")

# Function to split a list into chunks
def chunk_array(lst, size):
    return [lst[i:i + size] for i in range(0, len(lst), size)]

# Delay function
def delay(seconds):
    time.sleep(seconds)

# Regex pattern to extract GitHub repository owner and name
GITHUB_REPO_REGEX = r'https://github.com/([^/]+)/([^/]+)'

# Function to fetch cryptocurrencies with repositories
def fetch_cryptocurrencies_with_repositories(symbols):
    chunks = chunk_array(symbols, 100)
    all_cryptos_with_repos = []
    api_key = get_api_key()
    max_retries = 3
    delay_duration = 60

    for chunk in chunks:
        print(f"Fetching metadata for: {', '.join(chunk)}")
        attempts = 0

        while attempts < max_retries:
            try:
                response = requests.get(
                    'https://pro-api.coinmarketcap.com/v2/cryptocurrency/info',
                    headers={'X-CMC_PRO_API_KEY': api_key},
                    params={'symbol': ','.join(chunk), 'aux': 'urls'}
                )

                if response.status_code == 200:
                    # Check if the 'data' key contains the expected structure
                    cryptos_info = []
                    data = response.json().get('data', {})
                    for crypto in data.values():  # Iterate over the values in the 'data' dictionary
                        for crypto_info in crypto:
                            # Extract GitHub repository info from the source_code URLs
                            source_code = [
                                url for url in crypto_info.get('urls', {}).get('source_code', [])
                                if url and 'github.com' in url
                            ]
                            
                            # Extract owner and repo name from the GitHub URLs using regex
                            repos = []
                            for url in source_code:
                                match = re.search(GITHUB_REPO_REGEX, url)
                                if match:
                                    owner, repo = match.groups()
                                    repos.append({'owner': owner, 'repo': repo})
                            
                            # Store the cryptocurrency information along with GitHub repositories
                            cryptos_info.append({
                                'name': crypto_info['name'],
                                'symbol': crypto_info['symbol'],
                                'repositories': repos,  # Add the extracted repos here
                            })

                    all_cryptos_with_repos.extend(cryptos_info)
                    break
                else:
                    attempts += 1
                    if response.status_code == 429:
                        print(f"Rate limit exceeded. Attempt {attempts} of {max_retries}. Waiting before retrying...")
                        delay(delay_duration)
                    else:
                        break
            except requests.exceptions.RequestException as error:
                print(f"Error message: {error}")
                break

    print(f"Total cryptocurrencies with repositories: {len(all_cryptos_with_repos)}")
    return all_cryptos_with_repos

# Function to fetch all cryptocurrency symbols
def fetch_all_cryptocurrency_symbols():
    all_symbols = []
    start_index = 1
    limit = 5000
    api_key = get_api_key()

    while True:
        try:
            response = requests.get(
                'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest',
                headers={'X-CMC_PRO_API_KEY': api_key},
                params={'limit': limit, 'start': start_index}
            )

            if response.status_code == 200 and response.json().get('data'):
                symbols = [crypto['symbol'] for crypto in response.json()['data']]
                all_symbols.extend(symbols)
                print(f"Fetched symbols: {len(symbols)}")
                start_index += limit
            else:
                break
        except requests.exceptions.RequestException as error:
            print(f"Error fetching cryptocurrency listings: {error}")
            if response.status_code == 429:
                print("Rate limit exceeded. Waiting before retrying...")
                delay(10)
            break

    print(f"Total cryptocurrency symbols: {len(all_symbols)}")
    print(f"Sample symbols: {all_symbols[:5]}")
    return all_symbols

# %%
# Fetch all symbols first
symbols = fetch_all_cryptocurrency_symbols()

# Fetch cryptocurrencies with their repositories
cryptos_with_repos = fetch_cryptocurrencies_with_repositories(symbols)

# Optionally, print some of the results
print(cryptos_with_repos[:5])
# Out:
# Fetched symbols: 5000
# Fetched symbols: 5000
# Fetched symbols: 156
# Total cryptocurrency symbols: 10156
# Sample symbols: ['BTC', 'ETH', 'USDT', 'SOL', 'BNB']
# Fetching metadata for: BTC, ETH, USDT, SOL, BNB, XRP, DOGE, USDC, ADA, TRX, AVAX, SHIB, TON, SUI, LINK, DOT, BCH, XLM, PEPE, LEO, NEAR, LTC, APT, UNI, DAI, HBAR, CRO, ICP, ETC, POL, KAS, RENDER, BONK, TAO, OM, ARB, WIF, FET, STX, XMR, MNT, ATOM, FIL, OKB, VET, OP, AAVE, INJ, FLOKI, TIA, IMX, FDUSD, GRT, BGB, ALGO, SEI, FTM, RUNE, RAY, ENA, THETA, BRETT, JUP, WLD, MKR, PYTH, POPCAT, ONDO, KCS, BSV, AR, FLR, BTT, XTZ, EOS, PNUT, FLOW, MATIC, LDO, QNT, STRK, BEAM, GALA, MOG, JASMY, KAIA, NEO, AXS, AKT, HNT, GT, AERO, CORE, XEC, GOAT, MEW, APE, SAND, NEXO, MANA
# Fetching metadata for: EGLD, PENDLE, DYDX, AIOZ, MINA, FTT, ORDI, USDD, ZEC, NEIRO, NOT, CFX, XDC, CHZ, GNO, XAUt, IOTA, ENS, W, BOME, LUNC, ROSE, AXL, SUPER, SNX, CKB, BTG, CAKE, ZK, CRV, GMT, PYUSD, PAXG, RON, BLUR, TUSD, 1000SATS, KAVA, ASTR, TURBO, SAFE, NFT, COMP, DEXE, JTO, EIGEN, ARKM, TFUEL, 1INCH, ACT, ZIL, WEMIX, WOO, TWT, RSR, CELO, MEME, ZRO, IOTX, OSMO, ETHFI, LPT, AMP, ZRX, DYM, ETHW, HOT, TRAC, GLM, QTUM, DASH, ENJ, CTC, ID, SC, KSM, BabyDoge, ZETA, PONKE, JST, ANKR, BAT, RVN, MANTA, SFP, GAS, LUNA, DOGS, AEVO, SOLO, ELF, PEOPLE, MASK, METIS, POLYX, IO, SKL, GMX, MX, ETHDYDX
# Fetching metadata for: USDe, ZBU, EDLC, FLZ, FTN, DOG, FRAX, CHEEL, VIRTUAL, BDX, ZEREBRO, PEPECOIN, GRASS, SPX, MGC, USDY, MOODENG, FARTCOIN, ORBR, CHILLGUY, GIGA, VRSC, DRIFT, MWC, FLEX, 1MBABYDOGE, TRIBE, TEL, ATH, APU, ALEO, NPC, CAT, SNEK, PRIME, CHEX, DEGEN, T, DSYNC, CVX, MPLX, ALT, LRC, BICO, VVS, G, DOGE, BITCOIN, ANDY, HMSTR, BORG, ONE, SSV, BANANA, DCR, FLUX, UMA, GLMR, SXP, ILV, PIXEL, ZIG, XCH, YFI, ONT, KDA, XRD, RPL, CFG, AVAIL, SUN, SUSHI, BAND, BLAST, FXS, STORJ, CSPR, ULTIMA, ORCA, WMTX, XAI, OSAK, XEM, YGG, COTI, $MICHI, UPC, AI16Z, MRS, SAGA, ACH, HONEY, DGB, QUBIC, BNX, CETUS, AUDIO, VTHO, ICX, WAVES
# Fetching metadata for: KUB, CPOOL, CHR, TRB, AGI, EDU, RLB, Gomining, SCRT, BIGTIME, LSK, VANRY, MERL, API3, DEUSD, SNT, USDB, CATI, SLERF, NOS, H2O, JOE, WAXP, MNT, HIPPO, CHEEMS, USDJ, POWR, POND, BAL, MUMU, LUCE, IQ, SUNDOG, ZENT, ONG, BB, IOST, MVL, CVC, X, DAG, SLP, BAN, ABT, NTRN, CTSI, XNO, ERG, RLC, ALPH, SCR, ZEN, C98, OZO, WOJAK, EURS, SPEC, USTC, XYM, DEEP, BORA, PRO, COQ, OLAS, CARV, XVS, RETARDIO, WZRD, BDC, MIGGLES, VELO, TAIKO, WOLF, PUNDIX, XYO, PAAL, SDEX, ORAI, ACA, CELR, SPELL, NMR, HIVE, CYBER, WEN, BASEDAI, MAGIC, LQTY, BONE, IAG, OAS, RIF, DENT, STRAX, FIDA, PORTAL, LON, USDP, AI
# Fetching metadata for: MYRO, KEEP, PYR, TAI, MOVR, USUAL, CTXC, TOSHI, JET, ARK, CTK, SHIBTC, ALI, XVG, TRU, MANEKI, ANYONE, MPL, AGLD, PCI, KNC, ANT, PROM, GAME, DKA, STEEM, ELON, ISLM, VERUM, LUMIA, COL, 0x0, PHA, CLV, HIGH, ARDR, UXLINK, DAR, ACE, APEX, ORBS, MLK, COW, COREUM, ZANO, SYN, MED, HFT, CGPT, MTL, BUB, WILD, DODO, MOCA, CUDOS, STPT, AUCTION, BOBO, OMI, EURC, PHB, SFUND, DUSK, NAKA, MOODENG, BMX, DAO, LCX, M87, NIKO, RACA, AZERO, SURE, WHY, AIAT, POKT, RARE, DIA, VELO, HOOK, TON, AURORA, HEART, BTRST, RIO, STMX, SYS, ALICE, AITECH, WIN, MAV, QI, ARPA, HIFI, UQC, MOB, REQ, LOOM, NYM, SLND
# Fetching metadata for: BNT, ZKJ, LADYS, HT, OMNI, $RIF, HOPPY, BZR, NEURAL, MCDULL, TLOS, MBOX, ARRR, BAKE, NEIRO, NKN, OXT, RSS3, OGN, ALPHA, SHDW, GNS, ZCX, NFP, MCT, CROWN, RDNT, LTO, AL, GODS, KARRAT, LUSD, TNSR, BUSD, GUSD, MBX, TRUMP, GPU, BADGER, QKC, ALU, LISTA, LEVER, RAD, KUJI, CET, SIGMA, STIK, VENOM, USDX, XPLA, STG, SHRUB, GTC, ZBCN, CBK, BFC, NMT, AIDOGE, ACS, REZ, MBL, LMWR, GEMS, DEAI, HPO, RSC, INSURANCE, vBUSD, CXT, BELLS, AEUR, SWEAT, DESO, PEIPEI, MOBILE, AA, VR, EUL, TET, TLM, FRED, DPI, RBTC, MAF, LOOKS, MYRIA, FIRE, FX, REI, SAUCE, DIONE, AERGO, BULL, PALM, META, DADDY, MAD, STRD, ALEX
# Fetching metadata for: TKO, LKY, VCNT, BLZ, ERN, ATLAS, AOG, OGY, HASHAI, GEAR, OX, WRX, ROOT, ATA, SWELL, PNG, DNT, TOKEN, BTCP, GEOD, MemesAI, FORT, AGRS, ACX, XCN, GROK, PERP, GHST, GST, MAVIA, FORTH, PRCL, BARSIK, MOTHER, USDL, LYX, ICE, PORK, SHOGGOTH, MIN, RARI, ELA, ALCX, CAW, LAT, SHX, GEL, CONX, PXT, NCT, POLY, DEGO, VVAIFU, ASM, BEL, GHX, VLX, DIMO, EURI, DMTR, OCTA, MAPO, TT, OMG, FLM, DATA, DORA, REN, HUNT, DEP, STRK, DEXT, TROY, MLN, AIC, COS, LUNA, MODE, SBD, TOKE, POLIS, GLDGOV, BOSON, EWT, GFI, HAI, ISIKC, LIT, NAVX, WHITE, KISHU, SKBDI, PROPC, RBN, BILLY, WAN, STRX, KMD, SD, ADS
# Fetching metadata for: FCT, VIC, SAMO, BETA, EURt, LOCK, ZEON, NIM, ALEPH, MNGO, GME, MCOIN, NULS, ETN, LINA, BWB, FLIX, CCD, XPRT, BRISE, NUM, FIS, CUSD, PIRATE, LOKA, GRS, EVER, PROS, LOCUS, DF, QUACK, 10SET, MATH, TRIBL, GAFI, BOBA, XSGD, VOXEL, MDT, ULTI, PROPS, AMPL, SIDUS, BSW, MOC, FARM, ROG, QUICK, DOLAN, RAMP, XWC, CHESS, QUICK, HYPC, AXEL, PHIL, FB, AQT, AHT, IDEX, BENJI, PSG, VRA, UOS, WAGMIGAMES, LEASH, KIN, WXT, COMBO, CREAM, CSWAP, MAX, POLS, SLF, BOTTO, COPI, UTK, GFAL, CEEK, FOXSY, LNQ, VINU, HGPT, BIM, RSV, DCD, SOV, SCA, REEF, KIBSHI, ORDER, DACXI, SIX, FT, PUFFER, OPUL, VAI, BFG, VRTX, LBT
# Fetching metadata for: AVA, eUSD, STT, THL, AIT, KENDU, FEG, TPT, KOKO, SHFL, PRQ, PDA, VIDT, ASD, NPT, HTR, USDG, KEKEC, MAGA, BZZ, UPP, GLQ, DNX, OMNOM, FUN, CHEQ, MASA, ADX, WING, IDIA, BURGER, FIO, DEVVE, NXRA, XPR, COOK, OHO, APX, GOG, ALPACA, TONIC, $URO, PUPS, AVINOC, EXRD, ATR, UFT, WE, JESUS, PAID, HEHE, GALEON, IRIS, SMOG, NUB, BOB, MPT, OORT, SKEY, SN, SHRAP, BIFI, PIKA, CAH, GTAI, SRX, XNC, NWC, LOBO, VSG, SANTOS, KRL, MPC, KYVE, SQGROW, BRAINLET, AMB, MUBI, oGPU, ZTX, PSTAKE, DMD, CLY, TRVL, HOPR, ZUSD, UNI, DLC, FLT, GINNAN, PIVX, HARD, NEON, FOX, UFO, NTX, DFG, KLV, RAKE, BKN
# Fetching metadata for: EL, QRL, VOLT, BFIC, STOS, OG, KEY, $DRF, TROLL, SDAO, MONA, OMIKAMI, XCP, GMRX, HEZ, SOUL, LWA, ZKL, PANDORA, BCA, XCAD, BOOP, WELSH, MON, SPECTRE, TARA, DERO, NPCS, BAR, CELL, IDRT, SELFIE, FIRO, AURA, A8, TRAC, DVPN, TORN, GUI, FON, COMAI, NAVI, IOT, INV, BIDR, GMEE, AKRO, PINO, PLU, MSTR, KASTA, MCADE, USDV, JHH, CERE, CLORE, SWORLD, KSP, NOMNOM, HAMMY, GFT, PSPS, LORDS, CAT, SMT, PENG, DCK, STEP, PEPE2.0, EPS, RVF, UNS, SLIM, SCS, DMAIL, FU, TIME, CITY, DC, TRADE, DIME, STUFF, KLAUS, HTM, WNCG, CTX, VARA, ALPINE, CAST, SCC, CWIF, VNO, SOLCEX, LMR, SHIDO, SHPING, MOON, PIT, KOIN, DEL
# Fetching metadata for: LIME, GAL, AST, QTCON, CATE, MOCHI, CRTS, MNW, JEWEL, DFI, KATA, BCD, UNCX, COIN, HEGE, VIB, MOVE, AURY, RLY, TSUKA, NEXA, SC, MXC, ZKML, ARIA20, CREO, AVT, SPA, PSP, HEGIC, HELLO, PDT, SWFTC, GYEN, DCB, CRETA, BLOK, LAZIO, ALT, YFII, DOP, RGOAT, VITE, BLENDR, SABAI, SPS, BABYNEIRO, BREED, SLOTH, ASR, NMC, BYTE, VXV, COLX, GNON, GRND, EBULL, SUKU, TBULL, BOND, DUKO, DBC, PNK, OFN, BLOCK, SOIL, CGO, LIKE, BST, STFX, WIFI, CWEB, JUV, SILLY, OAX, MDX, CHAT, AE, GLEEC, XCHNG, TAVA, MBS, PORTO, INDY, DVI, TAROT, GOAL, ADS, ZERC, NODL, RBX, KLIMA, TGC, FUL, SOLAMA, SAITO, PPC, SWAP, BXN, CENNZ
# Fetching metadata for: HOGE, BENDOG, NCDT, GAL, HOSKY, EVZ, KAI, AMO, OPEN, MVC, KAI, NGL, ACM, NOW, OBSR, UDS, ATM, SMURFCAT, RXD, WRLD, APRS, WOLF, AZUR, LQR, CREDI, PUCCA, SWCH, BUY, NYA, ARG, POLA, SERO, BCUT, PIB, CULT, KWENTA, HUAHUA, vLINK, STARL, ZUKI, REF, VCHF, BB, CPR, SDN, SNS, BOO, BNC, MCB, BURN, KOMPETE, LRDS, ICHI, CHAT, KP3R, SUSD, AFC, COK, THE, HERO, ARTY, NATIX, BEAM, BAD, HUSD, AGX, CRPT, EGG, DFC, QDX, MTRG, SCLP, SPURS, G3, MIX, OGV, METAL, EVA, WALLET, FAR, CEL, RYU, PPT, PAW, EFI, BUB, HEMULE, LM, POOH, 3ULL, SPEEDY, SHI, PALLA, CAGA, KAR, NYAN, ATS, GPT, RUSSELL, INTER
# Fetching metadata for: TADA, OPTI, ZYPTO, SYNC, LOVELY, BXX, PUFFY, POOLX, NUT, BIOT, GET, WLTH, TEMCO, SRM, BABYBONK, DHT, CSIX, BEER, SPC, $MONG, CTP, BTM, GMCOIN, OOKS, vLTC, BVM, WHALE, BAN, CHO, GMM, MAN, SDT, NIBI, NOIA, KIMBO, UNIBOT, CTY, IZI, UX, HAPI, CUBE, FITFI, INSP, PLN, MARS, CRASH, OVR, LUCA, QORPO, HNS, ADP, HABIBI, FEI, FUSE, HI, WIKEN, XZK, EXE, WOW, MEV, DRGN, ISK, PMG, REP, AKITA, HUND, CA, EQUAD, IVPAY, IVfun, KAN, THREE, LA, UNFI, GARI, UBT, TYPE, GZONE, vDAI, ZERO, PAJAMAS, DUEL, KEX, EPIK, BAX, FNCY, BRICK, POWSCHE, ABBC, PUSH, ELON, GBYTE, TRA, FANC, ZNN, IMPT, EMRX, AIPAD, XEP, PIKA
# Fetching metadata for: WARPED, KILT, FER, CARR, ASTX, BOOT, XEL, STC, BTS, ZF, OUSD, ROA, SLN, PLF, ML, CVP, ELIX, RJV, DPR, WNZ, HYDRA, RBW, MASQ, AVI, $TOAD, SQR, BDP, OTK, SIS, BTR, CRU, SCPT, ORNJ, SHR, MNTC, IMT, SPARKLET, NETVR, AZIT, APED, BTC2, BBF, PACE, XNA, BAG, ZKF, NEIRO, CRAI, LAND, SWASH, ROCKY, 5IRE, STBU, BABYBNB, CHKN, HDN, AREA, BITCI, SOFI, LBL, HAMI, APM, RAIN, VALOR, ALVA, UFI, XR, MULTI, MTD, MNEE, SYLO, LEDGER, PESTO, MLC, KINIC, DOGK, $WAFFLES, BBL, CEUR, TRIX, PTU, OOE, XRPH, PBX, VMINT, XDB, GO, TRC, CTRL, CPU, SHC, GRACY, ONE, ACA, CAS, PRE, JOY, RADAR, RPK, QGOV
# Fetching metadata for: NEX, MANYU, SCP, UMT, MARSH, GG, SENATE, SSWP, MOTH, UBXS, ID, DUCKY, MYST, LOGX, ORC, RWA, RISE, IMGNAI, CBG, INTX, TOAD, BEPRO, WITCH, ESE, MEE, MENGO, MNTL, WOM, BOA, YOOSHI, DIVI, WEFI, BLY, MCRT, NDC, STAT, NRG, VAI, WAT, AMON, SMILEK, VAL, GXA, PIP, TENT, REVV, BROCK, PKT, BSCPAD, BF, DOGA, SHIRYO, ANALOS, LL, TCAT, GENE, EPIC, BCN, MDAO, SOLVE, MV, WSI, DARK, SUNCAT, VERSE, DIO, VIX, IDLE, ETHAX, TKP, BIZA, RING, STRUMP, DRAGGY, LBC, VEST, PRX, CAPS, VTC, DFL, SAI, DEFIT, BIP, JETTON, RBT, DOBO, LEMON, SNC, CRP, ELGATO, SHIBDOGE, BRN, GONDOLA, OXB, NFTX, PLI, ANC, SGT, CIV, ZKB
# Fetching metadata for: BAAS, SPH, HANA, NHT, CATBOY, TORO, MUSE, AVL, CUMMIES, RPG, AIRDROP, PKF, UPO, CATA, ILC, RAI, MTV, IGNIS, FTC, MANC, IHC, VEUR, COVAL, DAD, HAM, MAHA, POCHITA, MTLX, OMAX, DOME, POR, PNP, AUTISM, DYNA, DJED, COINYE, MKUSD, SAITAMA, GRIN, QOM, GROYPER, GRG, WDOG, BASE, KYL, PERC, KDAG, BOX, RGT, EML, JAM, torsy, ORT, WSDM, HONK, FRONT, SIGNA, FRM, KCT, VGX, USDC(WormHole), ASTA, LSS, MLT, MILE, LAVA, FSN, SWTH, JGN, DHB, LNDX, MONOPOLY, ABEL, PORNROCKET, POX, NAP, CCT, GSWIFT, XFC, P3D, NBLU, BUBBLE, PMT, EFC, OBI, TABOO, ADM, YAWN, VSP, NEST, DDX, REV3L, PLX, XTM, BCCOIN, MINT, INTELLIQUE, HONK, SLOP, PZM
# Fetching metadata for: DIP, PZP, CGV, BLOCX, LAMB, SFI, EPX, TOWER, CPH, RITE, HMND, ISP, MUNCAT, REV, BLS, CHI, RMRK, TOP, RBC, BWO, WAT, KLEVA, VIDYA, FRA, KATCHU, CTI, CTA, XRT, vDOT, GAINS, WSM, SFD, XODEX, CTG, ABDS, ASTRAFER, DUREV, LABZ, GOVI, CBPAY, CATDOG, SAUBER, MSI, DICE, EVERY, BTX, DYP, MILLI, FUND, UMB, SENSO, MOBY, KICK, ASK, FCON, POLK, AIKEK, ZYN, CBL, GHUB, PMPY, MIR, PANDA, COOKIE, TUP, METFI, WEST, GSWAP, ACE, NOM, RIDE, PBR, SIN, JMPT, PLANET, NVT, MOUTAI, AMU, MOZ, COT, EFX, DX, SHOPX, MIND, TKS, MORRA, MNFT, OLE, XPM, PAXE, XED, BONDLY, SOCIAL, GEEQ, LFGO, ROOBEE, VC, NEURA, SKID, ELAND
# Fetching metadata for: PART, BOMB, BLOCK, ARTFI, WTC, CHRP, KOM, DOCK, BCUBE, CANN, WWY, ERTHA, LTX, MTA, AIMX, GLC, BEFE, ARKI, AXIS, FREE, ROOST, GAME, TAMA, SAKAI, MEMEAI, DINO, XTAG, BABY, BEFI, DG, CHEEMS, PICKLE, GNY, CATE, CCC, YOM, THG, RET, SKR, DAPPX, SHEZMU, XAR, SOULS, LYNX, ANDY, BRWL, VCF, UNIO, SYL, NBT, RFOX, GORILLA, SHFT, NEVER, MCG, FOFAR, PLYR, LCC, SHEB, WOZX, CATCH, BURN, vBCH, BBS, MITX, PAY, CDT, AGLA, ATT, VSYS, MTH, $WELL, XTP, BEAT, HEFI, BEND, DOUG, NVIR, MATT, $VENKO, FLAME, BGL, ITHEUM, FLAVIA, BIDZ, XOR, EMC, HZN, APL, TOMI, TDS, STRP, OOKI, GHOST, LVN, BIFI, YAI, FOR, MBD, ABYSS
# Fetching metadata for: EUNO, FORWARD, BTCST, WAM, SAM, KROM, BOZO, IBS, KUNCI, ARV, VTS, CAU, PCX, MAYO, MOOV, STM, HVH, GRLC, DUST, WAIT, ZUM, WECAN, UPDOG, BOLT, WLKN, XRP, ITGR, URUS, MCHC, WOOF, AEG, OTO, DOAI, GQ, SATO, RMV, FB, PXC, SSG, UFO, FYN, HTD, MAGAA, MAX, WOMBAT, GOZ, ONE, DOGE, MCO2, POLC, XTN, MDAI, GMMT, FEAR, GST, PERI, LITH, IPAD, KITTENWIF, UNO, QRK, GEC, MONI, K21, BSCS, BOSS, PLR, VEXT, XMON, TRV, POR, LPM, MTS, PEANUT, KSN, TEER, LONG, PUSSY, HOD, MARS4, GINUX, EGO, NEI, BABYNEIRO, TOKO, DFYN, LAYER, EXFI, BLT, HAKKA, GMAC, SUB, DERI, EBEN, ZAI, UNB, SAFE, VEX, KNINE, VISION
# Fetching metadata for: ZAPI, CRWNY, FEX, NABOX, SPIKE, AUTO, ECLD, DEFROGS, STRM, SOS, STND, DINGO, REVO, IPV, ZOO, SXCH, HUDI, PXP, DOGGY, XPC, DPET, EGG, ANUS, JOB, WEEBS, BIOFI, CTCN, SCCP, VLXPAD, XELS, KMA, BHO, YEC, PDEX, AM, XRUNE, RBLS, NFE, ZIK, RODAI, MAPS, GRV, BLP, VNXAU, EXM, VEMP, ORB, SKAI, BCOIN, CRT, HC, CWS, SPIRIT, SKYA, ADAPAD, JUICE, TPY, GFI, GOME, LBP, SMI, SOY, WNT, PLASTIK, PEEL, LOOT, USDs, DEOD, ONI, ELMT, MINTME, ETHO, IDEA, DAFI, IOEN, CARLO, SHA, ALY, TROG, EPIKO, XRPAYNET, HAWKTUAH, SYNC, INTR, BRG, NCN, AX, BIST, DSLA, SECOND, POS, XMV, ROOK, CEP, GOC, SLICE, 0xBTC, MOJO, SOLCAT, DECHAT
# Fetching metadata for: WELT, FO, BILL, MONA, MMIT, ODDZ, DPS, TIFI, MVP, XWG, LITT, O3, CNB, TIPS, AIRI, EVAI, FRTS, PUT, BLAZE, EDG, BABY, CBX, IZZY, ZAP, HMQ, BLAST, SPORE, LIGHT, UNIX, DTORO, CATGIRL, SKEB, ABOND, ECO, LRT, CWAR, SHROOM, DREAMS, TKAI, ARC, ORARE, ZOON, XBY, 1ART, RWA, TES, CVTX, PUMLX, AOA, HAN, NIZA, INSUR, DONUT, ASTRO, WICC, JAM, L2, CGG, FWT, SBET, ELMON, STC, TRAVA, NGM, ELDA, XCV, JULD, ELMO, PLC, NOGS, CONE, EVRY, SALT, GLCH, VEGA, DRT, SPARTA, KZEN, SUTER, DTX, BFT, GB, BASE, HOTCROSS, VES, LZM, PIRATE, NRK, RHYTHM, KONO, ROCO, SOFAC, WSG, FLX, SON, SUILAMA, LNC, AME, ZCL, MEOW
# Fetching metadata for: CLO, LTD, KRIPTO, DEFI, PAR, BELT, KEKE, BITS, TWURTLE, $MBAG, BMON, INFRA, PYM, CLOAK, OMC, SNFT, BTCBAM, PRISM, RAZOR, YAM, VPP, MMA, BULLS, CAT, GTH, NVDA, QUINT, LYM, PEAK, ZTG, FWC, NFTB, PMON, ICNX, VRT, WSG, JANET, HOTKEY, DEM, MEFA, LUFC, ALLIN, MABA, AKI, ZEE, UNICE, DONS, THN, MTC, WOOP, POSI, SCOTTY, OLY, IDNA, UBX, NAFT, STARSHIP, EXVG, LADYF, $REKT, DEC, DREP, SUMO, RAIN, FLIXX, X, QRT, RFUEL, AWC, SPO, FRIN, SRK, COBE, JOY, S4F, JENNER, ODIN, ETHPAD, LYRA, SYNC, TSUGT, PLT, GALO, HEC, DESU, WIF, BTCZ, TUNE, CFi, REGENT, BCMC, NSFW, GLINT, LOCG, STRONG, ZELIX, BABYTRUMP, OXBT, CSM, VEIL
# Fetching metadata for: CYC, QSWAP, CHEEMS, PNT, WFAI, FUKU, EXA, XNL, ISLAMI, BLINK, SELF, PAPI, DOGMI, YLD, AZ, AOG, DIGG, CATHEON, ROND, KINGSHIB, HPB, GALAXIS, NSBT, THC, BSHIB, WAP, MSTR, MOD, SCALE, MIST, INEX, SOV, HORD, MRST, CONV, PLOT, AVG, IGU, KABY, UDO, QDFI, ATOLO, LOWB, BABYTRUMP, TKING, SATA, AMC, HANDY, EARN, CIRUS, MARO, PVU, LDOGE, DCN, BABYCATE, OCTO, DON, AG8, KCCPAD, HAWK, CRX, HGOLD, BXC, ZER, AIT, TONE, OGGY, DOKY, APES, GOLD, SHRED, VIX, PLY, NFTART, NEER, FYD, AART, DEXA, BTR, SPFC, NUX, COT, MTVT, HYVE, AIRTNT, HSF, KTN, NetZ, METAQ, ND, SHILL, SHACK, EDEN, HYPER, WATCH, BMI, ESD, SHND, erowan, OIN
# Fetching metadata for: RFR, OCE, WOM, SKILL, GNX, BLANK, MF, MASS, CLEO, TIN, MPH, KANGAL, KINE, XY, CU, PAC, SILVA, TULIP, LINKA, GOAT, WNDR, OJA, KNIGHT, PKR, MAO, OLT, YOUNES, WSPP, RVC, WZRD, AIBB, PTF, RUFF, IBFK, DDIM, SOLZILLA, HIBS, EMR, SWOP, BRKL, PERL, XBC, DOSE, LABS, BRUH, JET, ACQ, PEX, LOE, MRX, LIFE, HUSH, NSO, SNB, LAIKA, CARBON, KING, BIRD, SATT, NORD, GLS, OPIUM, STEP, MSU, RB, DRC, ARCONA, SUNPEPE, KAT, MCOIN, GF, LNR, HNTR, LTRBT, ING, BALPHA, UBEX, SOUL, FOUR, KART, KLO, XLD, BLOX, SWRV, EM, RVM, RPG, MBLK, TREEB, PLSPAD, FOMO, BANK, KPN, OPEN, MEGALAND, NBS, PCNT, eRSDL, C20, SPELLFIRE
# Fetching metadata for: NINO, IDRX, TEM, UTYAB, SHI, DUCKIES, HBX, MINU, KIDEN, HGET, SHOOT, MOBY, SELO, MMAI, KMON, CLEG, GMPD, NINU, SWINGBY, KALM, PAINT, FEVR, PACOCA, IOI, PLAY, XPNET, BDP, TXL, OXY, KTON, ALA, CNTR, XLAB, HELMET, MOVEZ, KDG, ZLW, BIN, EXGO, CVT, ARES, RAPTOR, KUBE, ARIX, KING, TROLL, FARA, PDOGE, SAKE, CNS, DOGEMOB, 8PAY, COMBO, GOB, TIK, ASPO, MO, FINA, JIN, IDV, MAT, INXT, DDOS, JRT, XNO, VALUE, GODCAT, ALLBI, RAZE, CZGOAT, BANANA, MITH, TFBX, SWP, RITO, ORION, FBX, ROCKI, NFTD, APYS, SNOW, CAIR, YF-DAI, MOMA, PRNT, TZC, AXE, 0XDEV, CTT, COR, TITAN, FXF, CLS, UBDN, TRAXX, DOWS, QWAN, ZUM, CO, GC
# Fetching metadata for: NAX, MYRA, YTN, EMAGIC, NRV, GOF, DINO, EBA, DHV, HUSL, SHARE, AXIS, MUDOL2, FIN, CTT, GS, CTT, ACN, NYZO, TIDAL, PTS, POLI, GDAO, DAMEX, TADDY, DFA, LSD, PYI, SHARD, BAC, SPIKE, GAME, DXGM, OGGY, SLRS, DAWN, VDR, 2MOON, SMART, PWAR, SHOGGOTH, REAP, FREED, OBX, SBABE, KOAI, DOM, SALD, XCASH, PHNX, GMAT, POLX, ATP, HAWK, BUFFI, ARGON, DXL, FPFT, WOW, NEBL, CATMAN, PASC, DOGY, APRIL, DUCK, BUNI, POLIS, MSB, ALN, GSTS, RPZX, APN, TCP, SUNPUMP, WAG, BLKC, CRP, BURN, OPCT, KEYFI, DLORD, SENC, CSPN, EVY, CORGIB, DONA, NEU, TOMS, EZ, CRE8, MEME, PLAY, VAB, MOTA, UPI, FOC, FORM, BTT, FINE, GMD
# Fetching metadata for: BPS, RBLX, ASW, FCL, LFW, GENESIS, GARD, PRCY, ADF, GCOIN, BL00P, MAGE, DAPP, XCUR, YIELD, SKU, NEXT, BRY, SHIA, BCUG, DBZ, PHR, PPAY, NEVA, SNM, ALGB, TIP, MSWAP, PHX, BWLD, IPX, NFTY, COGI, JADE, BOUTS, RAGE, bPRIVA, NERD, PAPU, LANC, BUNNY, BOLI, SYP, BUSY, VSO, FS, EKTA, BHC, TOTM, SNOB, FBN, TROLLICTO, AZY, XHV, KAMPAY, ISEC, PAYB, KOK, MILK2, EVA, TCS, SPWN, BP, SNY, RGP, FANX, BTB, SKP, BTRS, SABLE, ORAO, PETOSHI, RUNE, TKB, PYRO, PRARE, BEM, MMO, GUM, TANK, ZYB, AIRT, BNF, 1UP, IQT, AZUKI, SHIELD, MEL, METAX, DOGES, SCONEX, FLASH, UNI, STAK, BBANK, SPUME, ATMOS, ZNZ, SOLX, LKR
# Rate limit exceeded. Attempt 1 of 3. Waiting before retrying...
# Fetching metadata for: BETU, AMA, DEEN, EGG, LGCY, HERO, 1EARTH, NRFB, SHOE, ERA, EGG, DNXC, RED, CORX, TBX, DOB, KFT, SMTY, MEMECUP, LFG, TWIN, A, ALPHR, NSURE, GOLDN, HTZ, TRR, MHUNT, BNANA, FUZE, GEO, SPORT, PEL, SAO, PRVC, TXA, KWT, XDNA, WIWI, ISA, INNBC, JOOPS, SNN, DOP, MOWA, MAWA, GRIMM, SWP, BYN, GAJ, ETHA, FIU, VV, KUV, MEVRV2, INN, NDX, LUC, LITHO, LUS, SKYRIM, ICE, RENA, VAL, TME, MDTK, UFARM, BTZC, GXT, SCHO, WQT, XGM, AFEN, ACOIN, PTP, LAND, AD, KWS, $OPHX, MAKI, SFUEL, VIVO, MARTK, ELET, ARCO, LEAD, CARE, GDR, SWC, BSL, ROOM, MATE, XUI, CNTM, YVS, PLANETS, CRDT, CPO, CYL, SEFA
# Fetching metadata for: ETNA, PIAS, ECU, FBX, PRMX, SFG, RUSH, STAKE, WSPP, ZCR, YFFII, USDT.z, ETH.z, APEPE, MEMEFI, MORPHO, OL, SATS, XT, ELIZA, JLP, NS, BTF, FWOG, PROJECT89, HTX, WBT, CNX, KRW, DBR, PEAQ, USD+, 3KM, PEPE, ZEUS, MAGA, BERT, SDAI, AUSD, HAPPY, rats, DOGE, RNT, UZX, VNDC, TRUMP, FMC, BARA, FRED, XENT, SKY, KMNO, CATANA, XTUSD, AIFUN, HUGE, BBQ, PIXFI, ELIZA, MMXN, DOGE, FRXETH, CHEYENNE, BUCK, OBOT, HGG, EGP, SOS, AVA, VISTA, USD+, EVAN, SMILE, PARAM, FOXY, THB, OMNIA, L3, WELL, SUWI, PIZZA, BLOB, P2PS, 1CAT, SHIB, ZND, USD0, TREMP, STOP, CROS, FIGHT, LUM, WBC, PEANUT, GHO, SBR, DOLA, SCF, PLSX, WSTUSDT
# Fetching metadata for: PAI, GOU, ANDY, XBG, APX, GGP, LIF3, GIRL, PEAS, TBC, FPS, TRUNK, LOAFCAT, COIN, SQT, AAST, VSC, TURBOS, CADINU, DAV, OCB, EBC, TBC, VIDEO, R/SNOOFI, POLYDOGE, CKP, POCHITA, PPT, AGIX, BNSx, USTC, TALENT, ALPHA, MOODENG, CHART, SQUID, SERSH, PUPPIES, UNA, BODEN, THOR, SG, OHM, MMUI, CEC, KEN, BUILD, X, BMAX, STRDY, AGETH, SEAM, GEKKO, 丰, UNP, ZEPH, SOC, PLS, BTCS, MEDUSA, CIRX, CATALORIAN, KON, BKOK, NAO, XAVA, MCTP, CVXCRV, GM, KHEOWZOO, MIHARU, AMO, SOMM, PIN, CDX, EURCV, X2Y2, YOURAI, GROGGO, MARVIN, BICITY, TAB, ETHS, FINA, ROT, KARATE, WYS, TLC, SMART, BIT, LVLY, CORGIAI, WHALES, BATMAN, RCH, ZACK, ABEY, EVMOS, DFT
# Fetching metadata for: LKI, CANTO, CHILL, ORDS, GYD, PEOPLE, SHIT, CHONKY, SEED, DOGWIFHAT, DAO, NARS, UNFK, TATSU, PIZA, MAJOR, SKOP, CAT, SENDOR, ECHO, DOPU, lolcat, VMPX, DECENTRALIZED, ALP, ELU, PRB, BSTC, SNSY, MSTAR, LOULOU, BOOE, EBT, SAVM, BUENO, POX, NOOB, COPA, BORK, ATOM, LOS, EMP, GENOME, AINN, VOW, EAI, ZEDXION, TRUMPCOIN, LCT, AXGT, MAYA, UNM, HDRO, RBT, UNLEASH, NIM, IMARO, MMSS, UGOLD, FISH, INS, ARCA, LAKE, DAPP, LIBERTA, MEN, AKTIO, NOTAI, DOE, INVITE, JFIN, IUSD, KOL, $ECET, VELAR, NIGELLA, OCTO, MNDE, BCA, FXD, RAB, LTT, APX, EGX, SAROS, PEPPER, BIRDDOG, SIRIUS, TRUMP, FAML, HALO, GAU, JUM, PEPE, FP, TIG, BOB, SAD, ITA, TRUMP
# Fetching metadata for: NUTS, QTLX, META, ME, AQUA, shibai, JNFTC, MCN, AARK, DAETA, MICHI, BABYPNUT, FALX, $WATER, EGGT, XDAG, FLS, WIGO, PAW, AEROBUD, LEE, DTEC, ARENA, YES, BNBX, NST, XPE, $MICRO, MEME, FTW, FURY, RADX, FEFE, GGAVAX, SYK, GHOAD, BOOM, ZAP, PI, WORK, KLAY, COST, SML, LAIKA, FTON, MIM, ECOIN, KASPY, SWEEP, FIT, LUMOS, DOGAI, ASM, DITH, YAFA, FTRB, IXS, F3, NLC, TDM, ECOTERRA, Liza, PIKA, NESS, WUKONG, OMZ, VPAD, NORMIE, BERRY, PACK, HEX, USD+, FREL, xDAI, NIOX, SQD, FROG, OMNI, FIGHT, NOTE, NEMS, AI, WALLY, DTBX, 47, TODD, IRON, O4DX, CQT, FDM, SINK, XB, TX20, MELO, NINJA, xXx, BOBER, BTCAT, PAI, FAKT
# Fetching metadata for: AIPO, CAP, WUF, XMW, FTR, DONUT, GDOG, ENG, BNBDOG, CHMB, LQ, MONGY, GOCHU, ARNC, HPY, KCAKE, SDOGE, HRT, SPACE, PUFF, QUNT, DORKY, MATAR, PNIC, MELOS, LUCI, BTCF, TND, ICPX, MKT, RABBIT, LFT, ZYGO, EVDC, ALOT, UP, PEP, NRN, XUSD, KPK, QANX, INTERN, HBB, EUROE, TC, RGAME, BBTC, DINERO, NYAN, cats, PRI, VP, MPAA, DOGS, SOON, AVDO, FI, SATX, CHLOE, PAC, NOCHILL, SCT, BEER, VELA, LENFI, PATRIOT, TDROP, BRIUN, PEPE, CHINU, MCONTENT, CHINAU, RUNI, AAX, U, LAND, CAI, XIN, LILPUMP, WSB, RTF, BPT, MONDO, 4CHAN, KASPER, GGG, EVU, SUMI, EXPERT, RWT, WAS, EShib, 888, BLD, LCI, B.S.C, MAZZE, USBT, VERA, ROKO
# Fetching metadata for: FLDT, TOM, PEIPEI, NAI, SWAGGY, XPAY, FAME, IPMB, KITEAI, STASH, ICBX, MSQ, DDBAM, FROX, STARS, HACHI, F2C, BTCMT, TOBY, VCAT, GYMNET, GNUS, CHOMP, STORE, RAIL, IC, BRETT, RFD, SUIA, GCB, GOHM, DOGI, MARSO, MEX, SMETX, AIG, EMT, AIN, WATER, NEW, BOBE, MAS, SATOX, BASEX, CCASH, SHORK, BCX, HIPP, SCOTTY, $TIME, ENO, CROWN, TST, STONKS, VOLT, WALTER, CUUT, BLASTUP, KLS, TRUF, EXIT, VERTAI, KABOSU, ROAR, SERV, THING, KIM, CBY, UAHG, PEPEBRC, SALMAN, SOURCE, BFM, MAGA, NEWM, BALTO, STON, EAI, DNY, DVRS, BSX, CHAD, ADASOL, PAYU, VIA, LILY, BEEF, LAZYCAT, RABI, CHAMP, XSAUCE, CVXFXS, PROPHET, SPURDO, PUGGY, MIHARU, CRYO, CRAZY, PDJT, SHARP
# Fetching metadata for: INDEX, OMD, AIR, BXR, BABYPNUT, DSFR, OVN, LIMO, FOOD, WVTRS, DSK, ULD, RWN, BALLZ, BOB, AGII, GBTC, DIVER, SUIP, GURU, SOK, TRUMP, COAI, THECAT, TOS, MWCC, $CHIDO, AVALOX, TRUMP47, SMX, OLEA, BABYPEPE, PEPE, CLUB, SUDO, $BULL, ZIK, LUNARLENS, ASM, TRU, KONET, HLPR, WINNIE, UXD, TYLER, WYNN, $TD, SMT, VT, UNDEAD, WXT, CHAPZ, RETIK, ARX, enqAI, PIIN, INFRA, BETS, LOOP, JCO, POKERFI, LBM, SEAT, SUBF, DIP, BARK, KNDX, OZONE, KAP, ROCK, SHISHA, CLNX, NUUM, $AIMAGA, CHMPZ, WOLF, DOGO, LUCKYSLP, TORA, $INA, MATT, BAG, AJNA, JANI, INTL, KCAL, EQUAL, ZPAY, NXQ, RYO, XAGX, BORED, SVTS, BISO, GM, GRL, OBICOIN, BTCV, NZERO, AGC
# Fetching metadata for: $INR, ORE, UDAO, ESTEE, SBR, sICX, X, USEDCAR, ORACLE, MNFT, SCUBA, ALASKA, SOPHON, FFM, LOVELY, TOKU, SHIT, GBEX, QUANT, IBTC, LOTUS, KAMALA, NEIROINU, IDO, COSMIC, NOVA, GGMT, WFT, DAR, FINE, BNTY, $MEWING, BAKSO, WIC, AABL, WXM, LCRO, GRELF, SIO, EGAX, BECX, YLAY, TOON, SEAL, BOMB, RDT, TAL, CROID, PBUX, DEGOD, LFIT, JSET, TCAT, RATS, BORING, MGP, SUT, KINT, XNK, MUMU, LEVE, GCAKE, VANA, 1SOL, SHARKI, ELONIA, HBARX, CAMT, CTRL, 00, FTD, GNX, AUC, ALPHA, USDZ, MDT, KOL, HISS, BOZO, AIUS, SHIBAAI, SKG888, UT, LFNTY, GTN, SB, NKYC, RECA, REAL, A4M, UNMD, SOLETF, KBC, XNET, NALS, PEEZY, CTB, WEL, NFD, HBT
# Fetching metadata for: BNY, OKAYEG, TAP, CFN, DEVE, SDR, SISC, TBANK, ALI, GRIMACE, SING, BTCB, VT, CAPY, PCH, TROVE, CORN, CSAS, KAMA, COFFEE, ALL, PICA, PIKACHU, PGPT, URS, JWIF, MCAKE, MAXETH, OBT, ZAPO, CHIB, AXT, HAROLD, FRATT, PLT, PUMP, APE, MTLS, $LIQ, SFTMX, BNX, EDAT, GOAT, LONG, ROSX, VITA, TAONU, DOVU, SOLNIC, SOBA, SHARP, PEANIE, CAT, SEILOR, NGTG$$, EURA, DREAM, ORFY, LUAUSD, MARU, PNDC, CNG, OZONE, HAHA, DOC, GXE, VRC, ZOOMER, CATX, FAH, NEIROH, KT, MEDIA, GPTPLUS, OCT, LABRA, COME, SEOR, $RDF, APP, MAJO, PIX, HIT, AST, AURA, DOGEI, TGT, TENET, UBU, MZK, MXM, SKLAY, WECO, ARMY, MONK, LEMX, MUNITY, MATRIX, DJT, ORC
# Fetching metadata for: PLXY, JASON, BAKED, GTA, WX, SPACEPI, Cheems, MOLI, BYTES, EJS, GINOA, CLAP, $TOAD, OSHI, MOONLIGHT, USDH, AUR, HDX, PUNK, OILX, ECTE, XAI, CBSL, PBX, BTCT, BRETT, CANDY, CRH, ETH2X-FLI, D.O.G.E, GSYS, 4ART, LIFE, BORK, VIVEK, ZSC, SCAR, CTO, GHD, SAFE, FLAKY, DETF, 1EX, HOP, FACT, CELL, UPTOS, BBT, BOLT, LETIT, BRETT, BABYGROK, MOXIE, EURe, PME, ROBOTAXI, OGGIE, KIZUNA, LGX, BABYPOPCAT, GOOMPY, QDT, CDOGE, INU, ITO, DAGS, HYCO, TOPIA, METO, STOG, WEIRDO, ZZ, POUPE, XPX, GRAM, PATEX, EARLY, PURR, THALES, LBTC, $PELF, LUA, BTX, DPX, JUSTICE, ABRA, BIAO, WRKX, ACHI, SHIB2.0, UNIETH, MC, DAVINCI, BICS, IGUP, KRRX, SNK, VICS, XAH, BRUSH
# Fetching metadata for: VBG, EWON, PEPEGA, SOLID, RBIF, SOLY, LLT, CRONA, UXP, WIF, WOR, SMIDGE, BIF, PARMA, SHOKI, SPEEDY, SMR, PRICK, AIE, REFI, AQTIS, DOPE, MAGANOMICS, MOONSTAR, FLORK, SSNC, ROCK, LICKER, BABYBOME, SUNNY, AIMBOT, E8, BCT, KING, HOKK, POLLUK, TUX, DONKE, WGT, PEPEAI, SUNDAE, BNBCAT, VRSW, BPLC, $LOLA, LFG, CBAB, BABY NEIRO, DING, HOMER, TRUMP, DOPA, MOJO, RING, NTO, JDO, AIRBTC, CASTLE, BULL, MTRM, ATM, VENT, VOLTA, JERRY, SUMMER, X, PLSB, CBE, NWG, VTX, BTRU, RWAS, PUMP, VEE, PINK, MDF, AGN, TINU, SHIH, WJXN, GPUINU, PEEPO, SKING, DILL, JEETOLAX, BITB, NICOLAS•PI•RUNES, BONKE, DBI, LTX, DINGER, D2T, PEPEWIFHAT, CFXQ, MJT, DGH, WAD, BSW, SQUOGE, GREMLY
# Fetching metadata for: UVT, PLSARB, LIQ, ELON, GOKU, LGO, PLS, NLINK, DJT, GFLY, ITP, $TMNT, PPFT, LEN, XERS, PLEB, ASH, TATE, CYPEPE, SKIPUP, WEB4, LORGY, BARRON, SEA, ROME, TAPROOT, FWOG, MELANIA, MAGA, SWIFT, PESA, SIMP, XMT, ADOG, POKEMON, KABOSU, PEON, PORT, POPDOG, $BSV, STARX, APE, FTX, NAOS, NEWS, LONG, SCREAM, ISHND, LMAO, HMX, KAT, MONEYBEE, PSY, ITEM, JVT, $JAGO, AVO, GDT, CAT, XCRX, LIKE, AKOBI, MEMES, BUCKY, XTRUMP, XAI, BAY, SOLYMPICS, TPAD, HXRO, TIGRA, LIT, GONG, GROK, PENIS, GBL, SOLBULL, DAOSOL, IVIP, GTC, ITSB, SCRAT, GIGA, RED, POOCOIN, YFO, TRUMP47, AKITAX, BBC, TRUMP47, PREAI, DTG, MOLLY, EDSE, BRETT, MADA, POPEPE, TRUMPDOGE, TTC, SOLS
# Fetching metadata for: LEMC, $YAKU, TRUMP, SPIZ, JEX, REDZILLA, VIZION, WSB, BAI, IDYP, CIF, YUGE, BTCPX, AMS, MIXER, FIWA, BIRB, BANK, $GAMBI, IXIR, FROGLIC, BTH, GM, MOODENG, GPT, SDX, PANDO, KOSS, NEX, COL, PINE, CRYPTO, RIN, BLUE, DD, KLEE, SRT, MAMBA, MEPAD, BOOB, SAN, SHIBGF, MEOW, BEAR, PREMIA, HANU, ELS, DDD, GZX, DARIK, CHUCHU, $SLIME, MTC, ZIX, ANIMA, ETPOS, PIGEON, RSTK, SNOOPY, FLURRY, BAMBIT, NMX, UNITS, TOSHE, $CHILL, LINQ, BRT, LUNAR, FTW, MEME, REX, KRAZY, MCF, MIMI, MOLLY, SR30, TRUMPSHIBA, MLXC, EATH, OS, BAREBEARS, GLFT, GROK, AKT, FUEL, WIF, WX, 4WMM, FUG, CAT, LODE, HACK, KITTY, POP, MVERSE, KEK, RXCG, IVI, ZKID, OXO
# Fetching metadata for: TROLLS, INFI, TRUMPWIN, GLORY, BNBLION, HAT, RIBBIT, DOGS, SAFEBULL, BRCT, QWLA, GCAT, UTG, LFG, GNC, BNBCAT, MDS, HPO, SIMPSON, REAU, SAUDIBONK, TRUMP, PAPER, CODEX, PAYD, EDE, AFP, NYE, MFERS, BPINKY, PONKEI, LSP, SB, RAM, EOTH, MIS, DEXIO, LPL, GOATAI, APAD, CYS, GINZA, JP, BOG, BOMB, KAIJU, SLNV2, SNOLEX, AION, NOLA, VBNT, GINGER, POU, VDG, PINETWORKDEFI, SPY, RAMA, RAFFLES, $CORGI, SMARS, SHEESHA, DXD, FOMO, KBOX, LICK, DENTX, SHICO, SHEI, CYBONK, SLORK, RAMEN, DOGGS, TAXI, WLFI, DFH, TRUMP, ZEUM, CHP, DOGIN, MD, GBURN, OPS, FILST, FUFU, ARX, BULL, SLT, DFIAT, DOGEPR, XBTC, TIA, BDT, ICONS, CZUSD, WKD, JOHNNY, SOH, RS, SOUL, MAGNET6900
# Fetching metadata for: MAX, MBASE, CLOKI, BABYPEPE, $WHTETGRMOON, ARKY, TRUMP, BASED, RABBIT, ALMAN, ZIPT, DANA, TLW, SHIB2, UCM, PMM, BPET, PEPE, LOWQ, SOLKIT, VFOX, PEPECASH, CWA, XKI, SLUMBO, DEGEN, NBP, GCAT, $DTJR, DUGE, HERMES, FAR, DCT, RBX, BIC, ZYR, OCP, MOJI, MILO, WOME, NIOCTIB, BANANAS, STAR, $MANGA, SATS, HB, JTS, SOLR, BNBX, DORK, TALAHON, OME, SOFTCO, PEPEG, FIGHTMAGA, SHARE, WMEMO, DKNIGHT, WMOXY, PLT, TRUMPCATS, CRYPTON, PAWSTA, MOB, DOGS, ONC, TARI, ITO, BEN, SNOWBALL, MUSD, SMRAT, MOONBIX, LOST, BAJU, THAVAGE, D.O.G.E., NEGED, DCM, PUNGU, HAMI, OSK, MDA, SGT, SOLFI, VX, BBL, TKD, BAKED, BABY, UNQ, POPE, TIGER, wPWR, POTS, HOG, MAGACAT, OXN, TELE, RIN
# Fetching metadata for: ACE, KGC, BD20, AOC, BABYSORA, KINGSORA, BABYTROLL, CGU, MUTE, NCT, HATCHY, NODIDDY, RDO, GLR, SPL, MINI, CAF, CARO, BANKSY, GLXY, USSD, BLOO, QASH, GERMANY, EURC, 369, HUNNY, WACO, CLIMB, HZN, SHANG, Mononoke-Inu, BOC, RIVUS, MOON, BNK, LPNT, MNZ, PALMY, OSEA, ACRIA, JOJO, CREAM, SILLYCAT, LED, MOONS, ADACASH, XMS, BABYMYRO, PEPESORA, SRG, TYSON, GTA6, WAR, PEGA, XRX, IUS, DRAGON, CHED, AIGPU, VPK, TITA, X8X, NUSA, WATT, BAG, 0x0, SDME, BOG, PAF, FORE, BADCAT, NLC, CEM, TWD, HUB, BROGG, RAFT, BESA, SHIBA, AES, PLACE, YYAVAX, SLB, GTE, $BLUE, CRX, BBB, CRAZYPEPE, REL, ZPT, BOD, PER, PONZI, X, VATRENI, LCR, TMRW, SHDW, PAYT
# ...
# Fetching metadata for: DOJO, BS, TALK, BABYTRUMP, LYRA, WIFCAT, QUO, $SIXPACK, SWITCH, GROW, MGKL, PST, GAMEFORK, CCT, SKO, BLACKROCK, GEMS, PIN, KNOT, $SNRK, TIG, GCC, PWT, BLACK, ATOPLUS, VKNF, KRN, COLLECT, KNK, ALTB, WLFI, START, AII, ZINC, TGRAM, PARA, NORA, UE, KBC, TRUMP2024, MSOT, SHG, OREO, CHT, RENZEC, 2192, DOGE, SOBB, SMIDGE, BULL, SMUDGE, PLERF, PROT, LONG, CRAZYBUNNY, ORT, SALT, DOGEGROK, WEB5, LIEN, BODAV2, WIF2, YOURMOM, TRP, BURNS, GERA, SPADE, CRED, TBC, MVU, GUAP, VIDYX, WHEN, BSTS, FUTURE, PPAD, $BABYDOGEINU, TRUMP2024, BTC70000, SMUDGE, BABYFLOKI, MINIDOGE, QUIDD, PUPU, IMT, BABYTRUMP, MMT, PNDR, HOME, VBSWAP, BULL, HARE, KSHIB, MCT, PRTG, BIGLEZ, KPL, H2ON, BON, KIT
# Fetching metadata for: XGOLD, WEVE, GSF, AMBER, APU, GEO$, RUSD, CRK, MOODENGWIF, MEOW, SUNMAGA, YIKES, SOLBO, HOOD, KRS, EDOGE, AUR, LICO, VAPE, ADDY, CCO, RXT, WIFC, SWIM, MICKEY, TALES, AMBR, AMT, SEED, LUBE, PNY, CTR, GOFX, OBS, TRUMPCAT, EXO, SWOLE, FLOKI, ARENA, MART, SCROOGE, MTG, AMPLE, BOAM, WHETH, PET, NAZA, DIGEX, NS, EMAX, CHANG, MEOW, AGA, FINALE, ONX, FUNDX, PANDA, SKULL, OATH, HZD, PRXY, RXO, MEOW, CAT, IUX, WIF, BOSSCOQ, MNB, BUNNY, $PAIRED, FILES, PEPE, MSG, PAC, TRCL, ROUP, BOSOL, AMI, PEPE, CHINAZILLA, TBEER, BRAINERS, VAI, CRIPPL, PRIDE, MAZI, EKOC, KAMA, USHARK, EAGLE, WANA, CATS, TWEETY, ETH 3.0, PEARL, DTRUMP, YORI, BR34P, LEMO, PNL
# Fetching metadata for: IHT, SAFLE, TRTL, POWELL, TRUMP2024, FLOKI, LEOPARD, CORAL, NFTS, CMONK, PONKE BNB, BNBDOGE, BXH, SOBULL, ANDY, LUCHOW, CATDOGE, TINC, VOLX, RPR, OT, MCT, EDRC, SELF, OCW, AIST, DFSM, TPU, JEN, LSC, RBX, ICE, Ari10, GRIMEX, CAT, BIS, DEDE, BSTY, MOONED, BTCNOW, EYES, RUN, WLFI, MOM, SLIME, SYA, SOL10, DCLOUD, PEPEFLOKI, DRAGON, DARK, $LORDZ, PERRY, VSTA, RPC, BREWLABS, BNTY, ETHEREUM, MMSC, PAR, CYBERTRUMP, PSB, CATAI, TCGC, TIME, STEMX, KPHI, KOGECOIN, MNTG, TRDG, GIP, BPAD, UMI, SPHRI, RDDT, BUNNY, LOTT, CPS, LUNAT, CND, DLC, BABYNEIRO, MATA, GTTM, JPYC, COFI, DEXG, SWORD, ZOO, TRUSTNFT, HEDG, FOX, MMM, LIZARD, BABYKITTY, BNBSNAKE, QBT, SOP, PUGAI, SHIB
# Fetching metadata for: TRUMP, HNC, PIERRE, VEX, TOOLS, XLS, MINO, CARL, MOE, RNDX, FLOKICASH, FLY, QUACK, REIGN, TRUMP, GROKINU, OPT, SIB, AXIA, KINGTRUMP, SWISE, ABCD, MCC, STUSDT, ZKDOGE, BOOM, MRCH, FDC, BANK, AIX, BNBBONK, TRONP, BOBBY, SOAI, CBANK, GNFT, KALA, METANO, LEX, TCT, PSYOP, GOLD, TERA, XENO, IAI, COAL, BNBLION, JERRY, KURO, HUNDRED, BEET, ATD, DPLTR, OPP, QINGWA, BTCDRAGON, RUNEVM, LET, SUB, USHIBA, MARIO, LAB v2, MTIK, CATE, IQT, FMA, POODL, DRAC, ANY, PUMP, BILLI, FFTP, BULT, DMC, Milk, BAI, WUKONG, GSKY, BABYPORK, DMA, DRAGONKING, ACT, KITTY, MIX, ALIEN, SOBER, ANK, CYM, DOGE, KEY, RYU, SKI, NEIRO, FLOKIX, SnipPEPE, DSHARE, VRS, SHIBU, AXN, VC
# Fetching metadata for: DOGE, CRAZYCAT, SOLGUN, FTI, DOGE, FATHER, BALA, ROE, CAT, QBT, DOGGO, BRTR, USH, LOAN, DCRN, SPEND, COME, ZDEX, MINIFOOTBALL, METADOGE, PACT, MSCP, CHR, BABYDRAGON, BRETTA, SPEED, BNBSONGOKU, FUD, MORPH, ERA, LION, ZUSHI, DOGE, REM, SPD, FROYO, DEGEN, GLINT, SMARTLOX, CHEF, DMD, WOLF, XUSD, GEMS, TARO, MCLB, DUET, VOLTZ, POP, DOGSWAG, MCOIN, GGT, CAT, TERMINAL, CRAZYBONK, TMN, ANTC, DROVERS, ABX, SEX, CASH, META, TRUMP2024, SMARTCREDIT, XLIST, FLOKI, LABUBU, SMF, BOME 2.0, CERBER, LFG, CNF, SWIN, ESH, TQRT, MIS, TANUPAD, OLIVE, ELEC, BTC, KCAT, EDE, TIGERMOON, LBLOCK, USDTV, PEPEMAGA, HOW, 1MDC, FENOMY, TNGBL, ETF, MEH, BETA, CHG, AQUA, CRUMP, MGA, DOBBY, COC, FUD
# Fetching metadata for: CALI, WEB3, BSAFU, STONKS, KAF, ALPHA, TOKKI, CAT, BNBFLOKI, BNBOLYMPIC, BONK, DRAGON, DRAGON, PROPEL, MFG, FLOKI, SPIDERMAN, LIT, CDOGE, MCASH, BLA, DFC, PEPE, CAT, DOGE, MINU, BONKINU, MAG, SONGOKU, MARSUPILAMI, BNBVEGETA, CAT, BEATS, CLOUD, SHIBA, DRAGON, DOGE, CRAZYMUSK, NBABSC, UFC, SIMPSONS, CRAZYTIGER, DSHIB, DXS, CAT, CHEESE, SZCB, NSTE, TUCKER, SWTS, MECH, ANG, DMS, BIX, HTO, HRSE, MOGUL, ANIM, DUN, $KEM, OPX, LGBTQ, BABYGME, GOD, BGUY, GELO, UNO, GAMER, TR3, CRAZYPEPE, PIVN, MPWR, SOLSPONGE, TAUM, PERRY, SLIZ, XIDO, CHH, REV, SAFET, ETE, BTCPAY, BART, HUM, EGGY, DBA, CLBR, EAGLE, FERT, PHRYGES, JOC, QUBE, KINGWIF, TRUMP, $BRICKS, HALLOWEEN, METI, BEE, CNNS, LBR
# Fetching metadata for: CAT, CRAZYDRAGON, BABYDRAGON, BSK-BAA025, CAT, SANTA, OGD, ESS, FXB, PATEK, BAMBOO, MLTPX, ACE, $YAWN, 2OMB, VNM, DAI+, SVNN, USN, VIP, BNSD, FLX, SRN, RIOT, SSU, WEC, XVC, CATGOKU, KAMALA, MIIDAS, NT, XTT-B20, SRLY, POINT, M, WSHIB, DDD, TALA, MNTA, MIB, xBLZD, ORE, BSCM, GTX, DEXSHARE, IMMO, MEMESQUAD, MON, GVC, DOGE-1, WOLF, SAFEGROK, BORED, SNK, SNE, R2R, QIE, WAT, GGM, FREN, XACT, BLBY, ATP, WOD, PEPE2.0, CVIP, FTHM, RPTR, LUNCARMY, PGN, PAW, TROSS, ALBART, MCRN, HARRIS, NOA, FROGGY, SHIB0.5, REUNI, PEPEFLOKI, ITAM, ARA, REAL, BG, BXR, L2DAO, DINO, SSS, TECH, MAU, TES, OPTCM, ASNT, HUSL, MOLK, VERVE, BAGS, MISA, DRAGY, PAM
# Fetching metadata for: HMR, CIX, DJT, MOO, DEAD, KAREN, ALDIN, ELMO, MARCO, DPAY, VMT, BTBS, SHO, DYOR, THEOS, DAL, POP, EFL, BASED, SPEX, GMEPEPE, TMED, SPOOF, USH, GLDX, DOGEP, CATME, MILK, 2049, CATEX, 3AIR, VIZSLASWAP, DMZ, AGI, FLX, GTCOIN, HARRIS, RAGE, CAT, mCELO, NERVE, FDLS, PEPC, BX, MIU, TXG, GOL, MAGIK, STA, BZET, ADEL, HMD, PirateCoin☠, DIK, RPEPE, MNB, LYD, FOMO, DNFLX, STZU, KPAD, MQL, LVM, WHX, FEED, UGT, ETHEREUM, QUA, USDB, STAR, NBOT, UPRO, SMARTNFT, POOP, ZOOT, OIL, AGA, OMNI, WEX, MTRX, HBOT, SOLPENG, DUROV, PTAS, MYTH, NEIRO, GTN, BRAT, MTO, UTT, AITIGER, PETER TODD, LIMEX, FTVT, CVAG, NFTE, TZU, PEON, YEL, FHB
# Fetching metadata for: DST, GUILD, BSCGIRL, XRP2, DXCT, TOZ, CRYSTL, CHIRP, DAILY, REV, METAN, XANK, $TIPSY, NUR, ECOREAL, ETH, BM, MMO, CHECKR, REVA, LPY, PORTX, MAID, BR, ASAN, IMAYC, MOOX, METAUFO, TORG, CRAYRABBIT, BOP, BNB WHALES, TBE, FHM, CANDYLAD, GMI, FTMO, BNBBUNNY, CLASS, MOYA, LIZD, DOFI, ECC, BLI, ATNT, WGC, PROTO, CITI, MNFT, FUSD, X, POCO, CZF, BASEHEROES, AITK, DLTA, GOO, NVC, DOGS, WABU, POLL, MAX, FIONA, CBT, SFTY, CAMP, YIELDX, CART, BTCP, CMCX, $LADYS, DLYCOP, GREEN, ASIX+, ZAMZAM, TOR, EON, ZCR, KING, HOOP, OSMO, HVE2, CLNY, VNDT, FIRA, SNS, VINU, RFX, CBBTC, PRIMATE, COLLAR, XUSD, BENX, CONK, PINU, STRI, MILLY, GEMINI, SKY, MIVA
# Fetching metadata for: GRAIN, GEME, DARA, KRO, JUSDC, PTT, NFTL, NPXS, MXGP, COLA, MEM, DOR, DRAGON, LIBFX, $PG, SOKU, MAGA2024, STORY, A.O.T, LUXY, USV, TRUMP2024, DOV, IETH, BTNTV2, WWD, SHRAP, EARN, NEKO, NIRV, ERW, KVERSE, BSC, BITCOIN, STRIP, SMTF, BHBD, LC, PEDRO, GNTO, ETHM, MOO, BULL, BITX, COOCHIE, PRL, API, USDz, CZ, SOLID, POLYCUB, CVSHOT, EFFORT, FOX, RBT, GOTEM, VITRA, XAI, KELP, BABYDRAGON, CMT, TBAC, 360NS, FKBIDEN, BD, ALPHA AI, OXD, BSP, TITTY, BLF, PDD, SURF, BOMEOW, MSCT, CBC, LOX, HALLOWEEN, SANSHU!, NTR, MAD, RATING, BSC, ZMT, MGPT, PRED, TX, GRAPE, AFC, TRAVEL, GUC, aUSDT, MFTU, RICE, LPC, CPT, GETA, BABYRWA, 1MT, WRC, MERGE
# Fetching metadata for: CCHG, YURI, AISHIB, GENX, NCC, ETRL, FUKU, SVY, STONKS, SODAL, VIBE, MOJO, PEPESOL, CHENG, HARRIS, BLK, SQUID2, SQUA, SOLIDSEX, VIT, AI, FROGCEO, JPGC, BANANA, SBZ2.0, FRP, BABYSWEEP, OSK-DAO, CZSHARES, VENTION, GME2.0, KPAPA, HEC, CORGI, TERZ, PIPI, PIZPEPE, TDAN, MST, PINK, KODA, SUI, CRAZYBUNNY, NOIS, MSHD, GFN, SFF, BWJ, ACPT, VGO, SCAM, SIR, SMKNG, DUCATO, BSY, BABY CZHAO, ZES, RGOLD, MINU, L3USD, FIGHT, EPS, NEXMS, DCHEWY, LINDACEO, POV, HGHG, HBIT, TRANQ, GROKMOON, STAI, CZ, HMNG, ZKPAD, SECT, SHIBKILLER, FOXGIRL, TRDC, ZUZU, FOUR, VIM, ZOO, ALTMAN, MGOD, ADAM, GMETRUMP, FRENCH, DLB, WAI, BIDEN, COME, STR, HOUSE, GURL, MTK, BSHARE, SELLC, BITORB, TRUMP, SMU
# Fetching metadata for: BIBL, BABYMEME, FELIX, HND, SPANK, BABYFLOKIZILLA, FTS, DQQQ, VITAL, HELIOS, RAT, IXC, IFC, ZET, TAG, NXT, HBN, 42, DOPE, RBY, BELA, XPD, PLNC, BITS, QBC, BLU, NYC, DRM, CURE, MOTO, C2, START, XDN, XST, CLAM, VIA, XCN, CARBON, EMC, RBBT, N8V, OPAL, PXI, SPR, BLOCK, CRW, XQN, OK, XPY, NXS, KOBO, WBB, SONG, LOG, XAUR, CF, BUB, UNIT, PKB, ARB, BTA, ADC, SNRG, XRA, CREVA, MANNA, AXIOM, GCC, EUC, VEC2, SWING, SANDG, DFT, ADZ, AV, LTCR, YOC, SLS, FRN, EVIL, RBIES, IMS, PEX, CAB, MOJO, POST, BERN, XHI, XBTC21, ZUR, 2GIVE, XPTX, LANA, PONZI, CTL, HVCO, GB, CHESS, CJ, ACES
# Fetching metadata for: TAJ, VLT, ZYD, DLC, MST, ASAFE, KURT, ENT, POSW, WINGS, VIDZ, ICOB, IBANK, FRST, ICON, CNT, ARGUS, SWT, NETKO, DIBC, BLAZR, ZENI, CXT, CONX, TRST, SCS, VOLT, LUN, TKN, INSN, MAY, ADK, PTOY, GLT, UNIFY, DCY, ONX, GXC, SOCC, PLBT, SKIN, GSR, SHDW, ONION, IFT, DLT, HVN, BUZZ, IND, ATB, RVT, COB, EVX, BLUE, EXRN, IBTC, ATL, ELTCOIN, UFR, PRIX, PAYX, DNA, BCDN, ERO, BON, PKT, WRC, UBTC, STAR, BRD, NEU, EKO, AIT, ARCT, HOT, AID, CPC, DMT, MNTP, NTK, TDX, POA, STAC, NANJ, XBP, ADI, DAX, TNS, AMN, MT, GSC, DGX, SKB, JOINT, DTRC, DGTX, SEELE, KNDC, OTB, KBC
# Fetching metadata for: TOTO, VIKKY, WAB, NBR, PRIV, KLKS, ARO, TCH, XOV, PKG, IG, EGEM, NTK, OBTC, YLC, PMA, HB, HAND, KXC, YUKI, FTXT, AT, BEET, FLOT, CYMT, BTR, EVN, HAVY, RET, AAA, CTRT, ROX, CMIT, QCH, TRXC, MIR, KNT, NRP, ZNT, DATP, TDP, MODX, WTN, ESCE, APC, XNV, BLTG, TVNT, SHVR, HERB, BECN, QUIN, EXO, HPT, TCAT, DCTO, JNB, SET, CCN, USDE, XUEZ, NAVY, LTK, ETGP, BHIG, BOTX, TRAT, HNST, ETHPLO, EOST, GEX, IMG, TSHP, BSOV, YCE, BDCC, MKT, SCSX, YEAR, BTCV, RSG, DILI, FNB, SMILE, CDEX, XBT, SYM, NII, AET, JDC, MON, FRED, BXC, ZTC, CPAY, HTA, SCOP, CLT, BIZZ, BALI
# Fetching metadata for: CCXX, JACK, ICH, BLN, LEVELG, VARC, CBET, VECT, SORA, STP, ZOOM, DGMT, PIE, CBU, GTF, RICK, YAM, ENG, XFUEL, USDF, KSS, OCP, JBX, XLT, DUST, ESRC, LIVE, EURU, GBPU, USDU, UCR, BID, SUP, TTX, EYE, MARS, AUSCM, DFD, LST, UNW, GYSR, AGOV, FOL, BAS, UCAP, A5T, vXRP, HNY, HUB, NYANTE, BANK, RARE, ACTN, MNTIS, EDC, vFIL, PFI, DEQ, MDX, PTM, VBETH, LAVA, HBO, HFI, BT, WHL, VISTA, ADCO, NS, MINDS, ASVA, SOVI, VIPER, RYIU, VEN, STR, DELTA, XUVx, HAUS, STN, BERRY, REFI, SCA, QTCC, XFIT, BCMC1, P3NGUIN, vDOGE, CHE, PIPI, LEV, MER, UMI, UPR, SETS, PALG, TFC, DINGO, USDm, CBD
# Fetching metadata for: DRK, SHIBAKEN, GENS, DAISY, SXC, XGC, VAMPIRE, HAKA, GTC, PLN, KOJI, EGG, ORT, ETL, AI, INVI, TAB, FOUND, CYCE, MNY, HIBIKI, MMS, RAID, SCO, SONA, BLOX, STF, AFR, YOCO, GEM, POOF, IJC, JET, XTRA, XBN, VEST, SWPR, LHC, STON, BRCP, KST, EBSO, DWEB, SHAK, INET, PIGGY, ORE, pWINGS, TFC, VIRES, UBI, NFTL, FINN, SGT, APECOIN, FEES, CT, MCASH, HWL, AGX, WPC, OOGI, CHLI, BLOCKS, CPOO, BSCAKE, ARC, SPN, FTR, FIA, DND, MOBI, CHFU, QDROP, COC, SHIBEMP, ADON, GLB, USTX, spritzmoon, HPL, APP, XM, SSGTX, KEYS, SUTEKU, SSG, FIRU, CLCT, UMAMI, LTT, SCRL, HDAO, WMW, BIVE, KRX, DEVT, XSTUSD, MODA, FCP
# Fetching metadata for: UIM, RBC, VADER, TATA, WAL, PRCH, SANDWICH, TPV, BTCBR, JOL, $KMC, CALO, PHX, CAKESWAP, PLS, OBS, LIFE, ZPRO, SMCW, SAVG, VCG, SHIBIC, SVT, DIGAU, LIQR, DBC, MRUN, LIB, EAGLE, KINGDOG, GKF, RADR, MARTIA, EPIX, METABOT, TOURISTS, DGMV, APPLE, 4MW, FORS, ACCG, PTX, RIM, VIS, FPAD, CVC, BRIT, SOMDEJ, ASDEX, FOOD, STRM, SFV2, SUBAWU, NESS, DEG, DAMZN, DTLT, DEEM, DVOO, DVNQ, DAAPL, DURTH, DSLV, RIF3, SCK, MEME, GOD, CLVX, BB, GBC, BYTE, BCITY, LGOLD, TVRS, NUC, LFT, DPDBC, DMSFT, VITY, TAX, NUDES, BABYOKX, BTP, ZIRVE, BTCA, GGR, ZENC, TMC, KALIS, KINU, GHC, BRIDGE, VIK, MAIN, $KYUB, KUKU, AVXT, RIA, PRDS, RLOOP
# Fetching metadata for: NUMI, ELTG, FIT, OMNIA, STEPG, EZI, BCHEC, SHINO, GFT, ASSET, S2K, SMETA, HOT, SHINJI, DYST, HITOP, OLOID, BlueSparrow, PEN, GAMBL, JEDALS, LOOK, USDF, START, MDR, VRSE, INU, WTN, DEBT, GICT, SHELL, APE, dKUMA, LAND, BEMD, XPRO, STKK, FOF, STD, MAW, POO DOGE, TINU, USDTZ, FIX00, LOG, SHAN, OBTC, O, CUSD, MCL, NTG, EDEL, 2GCC, MOONION, BHIVE, BONTE, ET, SOCCER, CAKEW, WMX, MEWC, USHI, HALO, ZZC, BAO, HQR, WDOG, TYRANT, NUTGV2, JPD, BBC, SILK, GLF, UPLOAD, ZFM, FBURN, PMR, DINERO, NIK, MBE, SHINJA, HLM, Y2K, HWT, LKT, LYFE, USP, NEFTY, ARENA, VEGE, KWAI, MECI, PLCU, AUD, HACHI, FUTURE-AI, FUND, CS, GLC, AVN
# Fetching metadata for: IFC, CARMIN, MPI, CTS, BEFX, AIAI, GAI, JADE, GETH, Reelt, DOKE, PLX, Soarx, TSUBASAUT, OPINU, ALIF, VARA, SATS, WOR, GDX, DAOP, UW3S, MUSK, CORTEX, CHT, DCA, MZR, AIDI, MINT, 4TOKEN, W$C, BOW, ZNX, MEED, AVS, SDG, MONKEYS, CHICA, WOLVERINU, FGM, FKPEPE, PLEB, PEPI, RUG, CRI3X, IYKYK, PPC, FRY, SHREK, WEN, VS, GRAI, PEAR, NGMI, ABO, EXT, JOEY, UTBAI, ROLS, PUPPETS, JW, AVR, BEEP, FSC, BIAO, TXP, BMW, ARCH, MAXI, FT TOKEN, GPN, LOL, LADYS, TRUMP, MOONR, NOSO, FARMS, KUSDC, WHEE, FRENS, VCORE, $GOAT, FUNCH, DON, FXY, PEPEW, GARU, CRHT, STKC, QXC, DAVID, 0XGAS, BNBDRGN, FOOM, LULU, BULLPEPE, LAC, SNPS, JARED, HOBO
# Rate limit exceeded. Attempt 1 of 3. Waiting before retrying...
# Fetching metadata for: CBBTC, METH, SolvBTC, EZETH, BBTC, MSOL, WZEDX, LBTC, WBNB, SolvBTC.BBN, RSETH, BNSOL, vBNB, MSTETH, USDC.e, WPLS, cbETH, TBTC, EBTC, BTC.b, PUFETH, vBTC, SFRXETH, ETHX, sAVAX, BSOL, slisBNB, LSETH, PUMPBTC, BETH, sSOL, SOL, CMETH, SWETH, RBTC, INF, STAPT, RSWETH, WAVAX, PZETH, AXLFRXETH, WRSETH, vETH, osETH, WCRO, vUSDC, VSUI, STRX, WISLM, JSOL, FBTC, HASUI, stTON, WTAO, WOETH, WQUIL, CRVUSD, WFTM, stMATIC, WMATIC, SETH2, WNXM, ankrETH, WCFG, WIOTX, WSEI, vUSDT, vXVS, WCORE, HBTC, RENBTC, stDYDX, WRBTC, WHBAR, CKBTC, USDbC, stSOL, USDT.e, WMNT, stTIA, ynETH, WKAS, WAPE, WXDC, WAMPL, WADA, EZEIGEN, stOSMO, stATOM, WLUNC, axlUSDC, WASTR, SCRVUSD, WEGLD, WEVER, WMOVR, CDCETH, LRT2, WNEAR, WMINIMA
# Fetching metadata for: EDGESOL, WKAVA, bnUSD, WWDOGE, WCFX, WPOKT, JUSDT, dlcBTC, BTCK, WGLMR, WBCH, STNEAR, WHT, vSXP, WALV, ankrBNB, WZETA, WBB, WONE, WOKB, WKLAY, stWEMIX, CKETH, TBTC, stJUNO, WCANTO, WVENOM, WKCS, stAPT, wROSE, WELA, WTFUEL, WFUSE, ankrMATIC, WTHETA, WNRG, WNEON, WOKT, WPI, STKOSMO, WCKB, stSTARS, TELEBTC, stINJ, WACME, stEVMOS, STKATOM, WBONES, stUMEE, WDOGE, stSOMM, WPKT, pBTC, WSHEC, ynBNB, EZSOL
# Total cryptocurrencies with repositories: 14893
# [{'name': 'Aave', 'symbol': 'AAVE', 'repositories': []}, {'name': 'Cardano', 'symbol': 'ADA', 'repositories': []}, {'name': 'Aerodrome Finance', 'symbol': 'AERO', 'repositories': []}, {'name': 'Aerovek Aviation', 'symbol': 'AERO', 'repositories': []}, {'name': 'Akash Network', 'symbol': 'AKT', 'repositories': []}]

# %%
# Save the results to a csv file
with open('cryptos_with_repos.csv', 'w') as file:
    file.write('name,symbol,owner,repo\n')
    
    # Usar um conjunto para rastrear entradas únicas
    seen_entries = set()
    
    for crypto in cryptos_with_repos:
        for repo in crypto['repositories']:
            # Criar uma entrada única como tupla
            entry = (crypto['name'], crypto['symbol'], repo['owner'], repo['repo'])
            
            # Verificar se a entrada já foi registrada
            if entry not in seen_entries:
                seen_entries.add(entry)  # Adicionar ao conjunto
                file.write(f"{entry[0]},{entry[1]},{entry[2]},{entry[3]}\n")

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import time
import json

# Load environment variables (GitHub token should be set in the .env file)
def load_env():
    load_dotenv()

def get_github_token():
    load_env()
    return os.getenv("GH_TOKEN")

def fetch_issues_count(owner, repo):
    """
    Fetch the total number of issues (open and closed) for a given repository.

    Args:
        owner (str): Repository owner.
        repo (str): Repository name.

    Returns:
        int: Total number of issues, or -1 if an error occurs.
    """
    github_token = get_github_token()
    headers = {'Authorization': f'token {github_token}'}
    
    def get_issue_count(state):
        url = f"https://api.github.com/search/issues?q=repo:{owner}/{repo}+type:issue+state:{state}"
        response = requests.get(url, headers=headers)
        
        # Handle rate limit error (403)
        if response.status_code == 403 and 'X-RateLimit-Remaining' in response.headers:
            remaining = int(response.headers.get('X-RateLimit-Remaining', 0))
            if remaining == 0:
                reset_time = int(response.headers.get('X-RateLimit-Reset', time.time()))
                current_time = int(time.time())
                wait_time = max(0, reset_time - current_time)  # Ensure non-negative wait time
                if wait_time > 0:
                    print(f"Rate limit exceeded. Waiting {wait_time} seconds...")
                    time.sleep(wait_time + 1)  # Wait for the rate limit to reset
                else:
                    print("Rate limit reset time already passed. Retrying immediately...")
                return get_issue_count(state)  # Retry after waiting

        response.raise_for_status()
        return response.json().get('total_count', 0)
    
    try:
        open_issues_count = get_issue_count('open')
        closed_issues_count = get_issue_count('closed')
        total_issues = open_issues_count + closed_issues_count

        print(f"Repository: {owner}/{repo}, Open Issues: {open_issues_count}, Closed Issues: {closed_issues_count}, Total Issues: {total_issues}")
        return total_issues
    except requests.exceptions.HTTPError as http_err:
        if http_err.response.status_code == 422:
            print(f"Error: Repository {owner}/{repo} might be invalid or private.")
        elif http_err.response.status_code == 403:
            print(f"Error: Access denied for repository {owner}/{repo}. Check permissions.")
        else:
            print(f"HTTP error fetching issues for {owner}/{repo}: {http_err}")
    except requests.exceptions.RequestException as req_err:
        print(f"Request error fetching issues for {owner}/{repo}: {req_err}")
    return -1

def filter_repositories_by_issues(csv_file_path, issue_threshold=500):
    """
    Filter repositories from a CSV file that have more than a specified number of issues.

    Args:
        csv_file_path (str): Path to the CSV file containing repository data.
        issue_threshold (int): Minimum number of issues to filter repositories.

    Returns:
        pd.DataFrame: DataFrame containing filtered repositories.
    """
    try:
        if not os.path.exists(csv_file_path):
            raise FileNotFoundError(f"File '{csv_file_path}' not found.")
        
        try:
            df = pd.read_csv(csv_file_path, encoding='utf-8', on_bad_lines='skip')
        except UnicodeDecodeError:
            print("UTF-8 decoding failed. Retrying with 'latin1' encoding.")
            df = pd.read_csv(csv_file_path, encoding='latin1', on_bad_lines='skip')

        if 'owner' not in df.columns or 'repo' not in df.columns:
            raise ValueError("CSV does not have the required columns: 'owner', 'repo'")
        
        filtered_repositories = []

        for _, row in df.iterrows():
            owner, repo = row['owner'], row['repo']
            total_issues = fetch_issues_count(owner, repo)
            print(f"Processing coin: {row.get('name', 'N/A')}, {row.get('symbol', 'N/A')}.")
            if total_issues > issue_threshold:
                filtered_repositories.append({
                    'name': row.get('name', 'N/A'),
                    'symbol': row.get('symbol', 'N/A'),
                    'owner': owner,
                    'repo': repo,
                    'total_issues': total_issues
                })
        
        filtered_df = pd.DataFrame(filtered_repositories)
        filtered_df.to_csv('filtered_repositories_over_200_issues.csv', index=False)
        print("Filtered repositories saved to 'filtered_repositories_over_200_issues.csv'.")
        return filtered_df
    except Exception as e:
        print(f"Error processing the file: {e}")
        return pd.DataFrame()

if __name__ == "__main__":
    # Example: Fetch issues count for a single repository
    #print(fetch_issues_count('safe-global', 'safe-token'))

    # Example: Filter repositories from a CSV file
    # Uncomment and provide the path to your CSV file
    csv_file_path = 'cryptos_with_repos.csv'
    filtered_repositories = filter_repositories_by_issues(csv_file_path)
    if not filtered_repositories.empty:
        print(f"Total repositories with more than 200 issues: {len(filtered_repositories)}")
    else:
        print("No repositories processed or filtered.")
# Out:
# UTF-8 decoding failed. Retrying with 'latin1' encoding.
# Repository: ArweaveTeam/arweave, Open Issues: 67, Closed Issues: 150, Total Issues: 217
# Processing coin: Arweave, AR.
# Repository: ARbitcoin/ARbit, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: ARbit, ARB.
# Repository: ava-labs/avalanchego, Open Issues: 143, Closed Issues: 652, Total Issues: 795
# Processing coin: Avalanche, AVAX.
# Repository: BeamMW/beam, Open Issues: 234, Closed Issues: 1519, Total Issues: 1753
# Processing coin: Beam, BEAM.
# Repository: bitcoin-sv/bitcoin-sv, Open Issues: 4, Closed Issues: 247, Total Issues: 251
# Processing coin: Bitcoin SV, BSV.
# Repository: bitcoin/bitcoin, Open Issues: 374, Closed Issues: 7904, Total Issues: 8278
# Processing coin: Bitcoin, BTC.
# Repository: ContractChecker/audits, Open Issues: 2, Closed Issues: 1, Total Issues: 3
# Processing coin: Battle In Verse, BTT.
# Repository: dogecoin/dogecoin, Open Issues: 160, Closed Issues: 1126, Total Issues: 1286
# Processing coin: Dogecoin, DOGE.
# Repository: paritytech/polkadot-sdk, Open Issues: 1494, Closed Issues: 1137, Total Issues: 2631
# Processing coin: Polkadot, DOT.
# Repository: AntelopeIO/leap, Open Issues: 125, Closed Issues: 741, Total Issues: 866
# Processing coin: EOS, EOS.
# Repository: ethereumclassic/ethereumclassic.github.io, Open Issues: 72, Closed Issues: 360, Total Issues: 432
# Processing coin: Ethereum Classic, ETC.
# Repository: ethereum/go-ethereum, Open Issues: 191, Closed Issues: 7962, Total Issues: 8153
# Processing coin: Ethereum, ETH.
# Error: Repository flowersolana/token-list might be invalid or private.
# Processing coin: Flower Solana, FLOW.
# Repository: dfinity/ic, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Internet Computer, ICP.
# Repository: Impactcoin/IMX, Open Issues: 1, Closed Issues: 0, Total Issues: 1
# Processing coin: Impact, IMX.
# Rate limit exceeded. Waiting 14 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Repository: jupiter-project/jupiter, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Jupiter, JUP.
# Repository: DevGodPlanet/jupterwallet, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: JupterWallet, JUP.
# Repository: kaiachain/kaia, Open Issues: 3, Closed Issues: 11, Total Issues: 14
# Processing coin: Kaia, KAIA.
# Repository: kaspanet/rusty-kaspa, Open Issues: 56, Closed Issues: 83, Total Issues: 139
# Processing coin: Kaspa, KAS.
# Repository: SGRTeam/SGR, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Leo, LEO.
# Repository: alcazarerc/code, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Alcazar, LEO.
# Repository: smartcontractkit/chainlink, Open Issues: 79, Closed Issues: 360, Total Issues: 439
# Processing coin: Chainlink, LINK.
# Repository: litecoin-project/litecoin, Open Issues: 61, Closed Issues: 503, Total Issues: 564
# Processing coin: Litecoin, LTC.
# Repository: decentraland/mana, Open Issues: 2, Closed Issues: 19, Total Issues: 21
# Processing coin: Decentraland, MANA.
# Repository: maticnetwork/contracts, Open Issues: 38, Closed Issues: 47, Total Issues: 85
# Processing coin: Polygon, MATIC.
# Error: Repository solcatcoin/solanacatcoin might be invalid or private.
# Processing coin: solcatcoin, MEW.
# Repository: MNTracker/MNT, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: MN Tracker, MNT.
# Repository: neo-project/neo, Open Issues: 217, Closed Issues: 1203, Total Issues: 1420
# Processing coin: Neo, NEO.
# Repository: nexofinance/NEXO-Token, Open Issues: 3, Closed Issues: 0, Total Issues: 3
# Processing coin: Nexo, NEXO.
# Repository: OnPlanet-io/onPlanetToken, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: onPlanet, OP.
# Repository: maticnetwork/contracts, Open Issues: 38, Closed Issues: 47, Total Issues: 85
# Processing coin: POL (ex-MATIC), POL.
# Rate limit exceeded. Waiting 17 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Error: Repository orgs/starkware-libs might be invalid or private.
# Processing coin: Starknet, STRK.
# Repository: stx-technologies/stox-token, Open Issues: 2, Closed Issues: 3, Total Issues: 5
# Processing coin: Stox, STX.
# Repository: opentensor/BitTensor, Open Issues: 33, Closed Issues: 302, Total Issues: 335
# Processing coin: Bittensor, TAO.
# Repository: uinb/fusotao, Open Issues: 0, Closed Issues: 1, Total Issues: 1
# Processing coin: Fusotao Protocol, TAO.
# Repository: tronprotocol/java-tron, Open Issues: 19, Closed Issues: 1521, Total Issues: 1540
# Processing coin: TRON, TRX.
# Error: Repository centrehq/centre-tokens might be invalid or private.
# Processing coin: USDC, USDC.
# Repository: stellar/stellar-core, Open Issues: 269, Closed Issues: 1456, Total Issues: 1725
# Processing coin: Stellar, XLM.
# Repository: monero-project/monero, Open Issues: 458, Closed Issues: 2643, Total Issues: 3101
# Processing coin: Monero, XMR.
# Error: Repository ripple/rippled might be invalid or private.
# Processing coin: XRP, XRP.
# Repository: acetdefi/acet-farm, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Acet, ACT.
# Repository: Achain-Dev/Achain, Open Issues: 4, Closed Issues: 13, Total Issues: 17
# Processing coin: Achain, ACT.
# Repository: AstarNetwork/Astar, Open Issues: 19, Closed Issues: 324, Total Issues: 343
# Processing coin: Astar, ASTR.
# Repository: aevapay-code/AXl-Codes, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Axl Inu, AXL.
# Repository: abalabdev/AXLCoin, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Axial Entertainment Digital Asset, AXL.
# Repository: brave-intl/bat-ledger, Open Issues: 45, Closed Issues: 220, Total Issues: 265
# Processing coin: Basic Attention Token, BAT.
# Repository: blur-network/blur, Open Issues: 7, Closed Issues: 38, Total Issues: 45
# Processing coin: Blur, BLUR.
# Rate limit exceeded. Waiting 18 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Repository: BTCGPU/BTCGPU, Open Issues: 28, Closed Issues: 259, Total Issues: 287
# Processing coin: Bitcoin Gold, BTG.
# Error: Repository bitgem/bitgem might be invalid or private.
# Processing coin: Bitgem, BTG.
# Repository: celo-org/celo-monorepo, Open Issues: 55, Closed Issues: 5186, Total Issues: 5241
# Processing coin: Celo, CELO.
# Repository: cryptoforextoken/CRYPTOFOREX-CONTRACT, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: CRYPTOFOREX, CFX.
# Repository: compound-finance/compound-protocol, Open Issues: 42, Closed Issues: 33, Total Issues: 75
# Processing coin: Compound, COMP.
# Repository: compounddev/Compound-Coin, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Compound Coin, COMP.
# Repository: curvefi/curve-contract, Open Issues: 26, Closed Issues: 23, Total Issues: 49
# Processing coin: Curve DAO Token, CRV.
# Repository: REIDAO/crowdvilla-token-sale, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Crowdvilla Ownership, CRV.
# Repository: gluwa/creditcoin, Open Issues: 4, Closed Issues: 4, Total Issues: 8
# Processing coin: Creditcoin, CTC.
# Repository: credittag/CreditTagChain, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Credit Tag Chain, CTC.
# Repository: Cryptocoin-Org/Cryptocoin, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Cryptocoin, CTC.
# Repository: gluwa/creditcoin, Open Issues: 4, Closed Issues: 4, Total Issues: 8
# Processing coin: Creditcoin Mainnet, CTC.
# Repository: dashpay/dash, Open Issues: 120, Closed Issues: 633, Total Issues: 753
# Processing coin: Dash, DASH.
# Repository: dexe-network/DeXe-Protocol, Open Issues: 2, Closed Issues: 0, Total Issues: 2
# Processing coin: DeXe, DEXE.
# Repository: Layr-Labs/eigenlayer-contracts, Open Issues: 29, Closed Issues: 47, Total Issues: 76
# Processing coin: EigenLayer, EIGEN.
# Repository: greekmythologytokenBSC/GMT_Token, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: GreekMythology, GMT.
# Rate limit exceeded. Waiting 20 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Repository: holochain/holochain-rust, Open Issues: 250, Closed Issues: 302, Total Issues: 552
# Processing coin: Holo, HOT.
# Repository: iotexproject/iotex-core, Open Issues: 141, Closed Issues: 1136, Total Issues: 1277
# Processing coin: IoTeX, IOTX.
# Error: Repository JUMPN-BSC/JUMPN might be invalid or private.
# Processing coin: JUMPN, JST.
# Repository: paritytech/polkadot-sdk, Open Issues: 1494, Closed Issues: 1137, Total Issues: 2631
# Processing coin: Kusama, KSM.
# Repository: terra-money/core, Open Issues: 5, Closed Issues: 78, Total Issues: 83
# Processing coin: Terra, LUNA.
# Repository: DimensionDev/Maskbook, Open Issues: 7, Closed Issues: 2185, Total Issues: 2192
# Processing coin: Mask Network, MASK.
# Repository: MetaMask/metamask-extension, Open Issues: 1842, Closed Issues: 10101, Total Issues: 11943
# Processing coin: Metamask, MASK.
# Error: Repository memeticofficial/pepecoin might be invalid or private.
# Processing coin: Memetic / PepeCoin, MEME.
# Repository: MinaProtocol/mina, Open Issues: 686, Closed Issues: 5666, Total Issues: 6352
# Processing coin: Mina, MINA.
# Repository: ArtemisTheX/MarsX, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: MarsX, MX.
# Repository: NEFTiPEDiA/NEFTiPEDiA-SC, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: NEFTiPEDiA, NFT.
# Repository: azimin/digital-animals-contract, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Digital Animals, NFT.
# Repository: osmosis-labs/osmosis, Open Issues: 282, Closed Issues: 2004, Total Issues: 2286
# Processing coin: Osmosis, OSMO.
# Repository: paxosglobal/paxos-gold-contract, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: PAX Gold, PAXG.
# Repository: uefaeuro2024/EURO2024, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: MAGA, PEOPLE.
# Error: Repository PolymathNetwork/Polymesh might be invalid or private.
# Processing coin: Polymesh, POLYX.
# Rate limit exceeded. Waiting 14 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Repository: qtumproject/qtum, Open Issues: 36, Closed Issues: 296, Total Issues: 332
# Processing coin: Qtum, QTUM.
# Repository: patron-developer/patron-developers, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: RON, RON.
# Repository: oasisprotocol/oasis-core, Open Issues: 305, Closed Issues: 1545, Total Issues: 1850
# Processing coin: Oasis, ROSE.
# Repository: RavenProject/Ravencoin, Open Issues: 153, Closed Issues: 354, Total Issues: 507
# Processing coin: Ravencoin, RVN.
# Repository: safe-global/safe-token, Open Issues: 2, Closed Issues: 4, Total Issues: 6
# Processing coin: Safe, SAFE.
# Repository: Fair-Exchange/safecoin, Open Issues: 1, Closed Issues: 0, Total Issues: 1
# Processing coin: SafeCoin, SAFE.
# Repository: ScarpaCoin/ScarpaCoin.sol, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: ScarpaCoin, SC.
# Error: Repository delarosan1/SC might be invalid or private.
# Processing coin: Silver Coin, SC.
# Error: Repository CryptoUnited/SuperCoin might be invalid or private.
# Processing coin: SuperCoin, SUPER.
# Repository: ryaniyi/super-defi, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: SuperSwap, SUPER.
# Repository: thetatoken/theta-protocol-ledger, Open Issues: 45, Closed Issues: 26, Total Issues: 71
# Processing coin: Theta Fuel, TFUEL.
# Repository: OriginTrail/ot-node, Open Issues: 64, Closed Issues: 186, Total Issues: 250
# Processing coin: OriginTrail, TRAC.
# Error: Repository trusttoken/smart-contracts might be invalid or private.
# Processing coin: TrueUSD, TUSD.
# Repository: wormhole-foundation/wormhole, Open Issues: 81, Closed Issues: 860, Total Issues: 941
# Processing coin: Wormhole, W.
# Repository: zcash/zcash, Open Issues: 993, Closed Issues: 2846, Total Issues: 3839
# Processing coin: Zcash, ZEC.
# Repository: Zilliqa/Zilliqa, Open Issues: 102, Closed Issues: 284, Total Issues: 386
# Processing coin: Zilliqa, ZIL.
# Repository: zktube123/poriot_network, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Poriot, ZK.
# Rate limit exceeded. Waiting 16 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Repository: AltEstate/altestate, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Alt.Estate token, ALT.
# Error: Repository psabadac/aetherv2 might be invalid or private.
# Processing coin: AetherV2, ATH.
# Repository: availproject/avail, Open Issues: 1, Closed Issues: 45, Total Issues: 46
# Processing coin: Avail, AVAIL.
# Repository: jcroylegithub/BABY_DRAGONX, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Baby DragonX, BDX.
# Repository: trustwallet/assets, Open Issues: 1, Closed Issues: 1203, Total Issues: 1204
# Processing coin: SafeBlast, BLAST.
# Repository: blastdev/blast-core-v2, Open Issues: 1, Closed Issues: 0, Total Issues: 1
# Processing coin: BLAST, BLAST.
# Repository: bnrtx/bnrtxcoin, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: BnrtxCoin, BNX.
# Error: Repository Skemba/cyberarena might be invalid or private.
# Processing coin: Cyber Arena, CAT.
# Repository: catcoinwork/catcoinwork, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Catcoin BSC, CAT.
# Error: Repository kittyfinance/kitty-contracts might be invalid or private.
# Processing coin: CAT, CAT.
# Error: Repository chintai-platform/app-monorepo might be invalid or private.
# Processing coin: Chintai, CHEX.
# Repository: convex-eth/platform, Open Issues: 1, Closed Issues: 8, Total Issues: 9
# Processing coin: Convex Finance, CVX.
# Repository: soldegen/token, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Degen (SOL), DEGEN.
# Repository: idogcoin/DOG, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: DOG, DOG.
# Repository: wowodogdog/tokens, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Dog Coin[New], DOG.
# Repository: 01-finance/flux, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Flux Protocol, FLUX.
# Error: Repository PureStake/moonbeam might be invalid or private.
# Processing coin: Moonbeam, GLMR.
# Rate limit exceeded. Waiting 21 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Repository: cryptofun/honey, Open Issues: 0, Closed Issues: 5, Total Issues: 5
# Processing coin: Honey, HONEY.
# Repository: HoneyFarmFi/HoneyFarmContracts, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: HoneyFarm Finance, HONEY.
# Error: Repository HoneyDeFi/smartcontracts might be invalid or private.
# Processing coin: Honey Defi, HONEY.
# Repository: metaplex-foundation/metaplex, Open Issues: 93, Closed Issues: 1129, Total Issues: 1222
# Processing coin: Metaplex, MPLX.
# Repository: orca-so/typescript-sdk, Open Issues: 11, Closed Issues: 7, Total Issues: 18
# Processing coin: Orca, ORCA.
# Repository: UrsaMaritimus/orca, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: OrcaDAO, ORCA.
# Repository: rocket-pool/rocketpool, Open Issues: 18, Closed Issues: 74, Total Issues: 92
# Processing coin: Rocket Pool, RPL.
# Repository: sagaxyz/ssc, Open Issues: 0, Closed Issues: 2, Total Issues: 2
# Processing coin: Saga, SAGA.
# Repository: sagacrypto/SagaCoin, Open Issues: 2, Closed Issues: 6, Total Issues: 8
# Processing coin: SagaCoin, SAGA.
# Repository: decenomy/SAGA, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: CryptoSaga, SAGA.
# Repository: spixtoken/contract, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Spix, SPX.
# Repository: ssvlabs/ssv, Open Issues: 111, Closed Issues: 277, Total Issues: 388
# Processing coin: ssv.network, SSV.
# Repository: storj/storj, Open Issues: 437, Closed Issues: 2422, Total Issues: 2859
# Processing coin: Storj, STORJ.
# Error: Repository sushiswap/sushiswap might be invalid or private.
# Processing coin: SushiSwap, SUSHI.
# Repository: usde-project/USDE, Open Issues: 3, Closed Issues: 1, Total Issues: 4
# Processing coin: USDe, USDE.
# Repository: USDElectrino/USDElectrino.github.io, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Dollar Electrino, USDE.
# Error: Repository ondoprotocol/tokenized-funds might be invalid or private.
# Processing coin: Ondo US Dollar Yield, USDY.
# Rate limit exceeded. Waiting 18 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Repository: veruscoin/veruscoin, Open Issues: 15, Closed Issues: 19, Total Issues: 34
# Processing coin: VerusCoin, VRSC.
# Repository: vechain/thor, Open Issues: 0, Closed Issues: 138, Total Issues: 138
# Processing coin: VeThor Token, VTHO.
# Repository: grokxai/contract, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Grok, XAI.
# Repository: xaigl/contract, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: xAI, XAI.
# Repository: xaigd/contract, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: xAI, XAI.
# Repository: Chia-Network/chia-blockchain, Open Issues: 48, Closed Issues: 4924, Total Issues: 4972
# Processing coin: Chia, XCH.
# Repository: yearn/iearn-finance, Open Issues: 20, Closed Issues: 55, Total Issues: 75
# Processing coin: yearn.finance, YFI.
# Error: Repository 0xAppl/agility-contracts might be invalid or private.
# Processing coin: Agility LSD, AGI.
# Repository: cyberscope-io/audits, Open Issues: 0, Closed Issues: 3, Total Issues: 3
# Processing coin: Chat AI, AI.
# Repository: AICoinOfficial/AI-Coin, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Artificial Intelligence, AI.
# Repository: multiverseai/ERC20, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Multiverse, AI.
# Repository: yem583/DogData, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Bone, BONE.
# Repository: ChronosEx/Chronos-Contracts, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Chronos, CHR.
# Repository: Constellation-Labs/constellation, Open Issues: 145, Closed Issues: 486, Total Issues: 631
# Processing coin: Constellation, DAG.
# Repository: MystenLabs/deepbookv3, Open Issues: 4, Closed Issues: 2, Total Issues: 6
# Processing coin: DeepBook Protocol, DEEP.
# Rate limit exceeded. Waiting 16 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Repository: gomining-token/smart, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Gomining, Gomining.
# Repository: openhive-network/hive, Open Issues: 1, Closed Issues: 15, Total Issues: 16
# Processing coin: Hive, HIVE.
# Repository: IQ-Cash/iqcash, Open Issues: 1, Closed Issues: 1, Total Issues: 2
# Processing coin: IQ.cash, IQ.
# Repository: liquity/dev, Open Issues: 28, Closed Issues: 224, Total Issues: 252
# Processing coin: Liquity, LQTY.
# Repository: magicinuToken/Contract, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Magic Inu, MAGIC.
# Repository: mvlchain/mvltoken, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: MVL, MVL.
# Repository: neutroncoin/neutron, Open Issues: 0, Closed Issues: 21, Total Issues: 21
# Processing coin: Neutron, NTRN.
# Repository: scorum/cosmos-network, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Scorum Coins, SCR.
# Repository: scrtlabs/SecretNetwork, Open Issues: 31, Closed Issues: 547, Total Issues: 578
# Processing coin: Secret, SCRT.
# Repository: SmarDex-Dev/smart-contracts, Open Issues: 5, Closed Issues: 3, Total Issues: 8
# Processing coin: SmarDex, SDEX.
# Repository: ShareNft/sharenft, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Share NFT Token, SNT.
# Error: Repository SpectrumNetwork/initial_smartcontract_erc20 might be invalid or private.
# Processing coin: SpectrumNetwork, SPEC.
# Repository: zachdoty/peg-usdb, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: USD Bancor, USDB.
# Error: Repository paxosglobal/pax-contracts might be invalid or private.
# Processing coin: Pax Dollar, USDP.
# Repository: unitprotocol/core, Open Issues: 4, Closed Issues: 6, Total Issues: 10
# Processing coin: USDP Stablecoin, USDP.
# Repository: xai-cx/contract, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: X AI, X.
# Rate limit exceeded. Waiting 14 seconds...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Rate limit reset time already passed. Retrying immediately...
# Repository: XENO-NFT-Hub/eth-contracts, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: Xeno Token, XNO.
# Repository: token-stars/ace-token, Open Issues: 0, Closed Issues: 0, Total Issues: 0
# Processing coin: ACE (TokenStars), ACE.
# Repository: EOSIO/eos, Open Issues: 304, Closed Issues: 4750, Total Issues: 5054
# Processing coin: ACE, ACE.
# Request error fetching issues for burnace/burnace: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing coin: BURNACE, ACE.
# Request error fetching issues for Solidus-Ai-Tech/token: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Solidus-Ai-Tech/token+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C67D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Solidus Ai Tech, AITECH.
# Request error fetching issues for alita-finance/alita-token: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:alita-finance/alita-token+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C67D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Alita Finance, ALI.
# Request error fetching issues for ApeX-Protocol/core: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:ApeX-Protocol/core+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C4650>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: ApeX Protocol, APEX.
# Request error fetching issues for aurora-is-near/aurora-engine: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:aurora-is-near/aurora-engine+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C5B90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Aurora, AURORA.
# Request error fetching issues for Snowfork/BTRST-Contracts: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Snowfork/BTRST-Contracts+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C6FD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Braintrust, BTRST.
# Request error fetching issues for spayse/Bubble: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:spayse/Bubble+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C5450>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Bubble, BUB.
# Request error fetching issues for gnosis/cowswap: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:gnosis/cowswap+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C4850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: CoW Protocol, COW.
# Request error fetching issues for moneycowry/cowry: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:moneycowry/cowry+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7990>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: COWRY, COW.
# Request error fetching issues for lemonprojecttoken/cowfarm.finance: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:lemonprojecttoken/cowfarm.finance+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C6690>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Cowfarm.finance, COW.
# Request error fetching issues for cowtk/Cowtk: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:cowtk/Cowtk+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C5B90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: COW Token, COW.
# Request error fetching issues for muuuusk/tokens: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:muuuusk/tokens+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C6290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Cow Token, COW.
# Request error fetching issues for HiFiDeFi-Finance/Game-Factory-Contract: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:HiFiDeFi-Finance/Game-Factory-Contract+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C4490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: HiFi Gaming Society, HIFI.
# Request error fetching issues for TravisBuilds/HighStreet: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:TravisBuilds/HighStreet+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Highstreet, HIGH.
# Request error fetching issues for highgainqubit/highgain: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:highgainqubit/highgain+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C4850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: High Gain, HIGH.
# Request error fetching issues for jet-lab/jet-v1: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:jet-lab/jet-v1+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C5AD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Jet Protocol, JET.
# Request error fetching issues for mobilecoinfoundation/mobilecoin: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:mobilecoinfoundation/mobilecoin+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C44D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: MobileCoin, MOB.
# Request error fetching issues for cyberscope-io/audits: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:cyberscope-io/audits+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C42D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Mobster, MOB.
# Request error fetching issues for PureStake/moonbeam: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:PureStake/moonbeam+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Moonriver, MOVR.
# Request error fetching issues for qiswap/QiToken: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:qiswap/QiToken+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7F50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: QiSwap, QI.
# Request error fetching issues for radiocaca/radio-caca: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:radiocaca/radio-caca+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7DD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: RACA, RACA.
# Request error fetching issues for steemit/steem: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:steemit/steem+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C76D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Steem, STEEM.
# Request error fetching issues for StormX-Inc/crowdsale: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:StormX-Inc/crowdsale+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C6E50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: StormX, STMX.
# Request error fetching issues for inSureToken/SmartContract: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:inSureToken/SmartContract+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7D50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: inSure DeFi, SURE.
# Request error fetching issues for CryptoIcarus/SynLev: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:CryptoIcarus/SynLev+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: SynLev, SYN.
# Request error fetching issues for syscoin/syscoin: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:syscoin/syscoin+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C4810>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Syscoin, SYS.
# Request error fetching issues for nutsfinance/stable-asset: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:nutsfinance/stable-asset+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C5AD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Taiga, TAI.
# Request error fetching issues for trusttoken/truefi-spec: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:trusttoken/truefi-spec+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C4F10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: TrueFi, TRU.
# Request error fetching issues for WildCredit/contracts: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:WildCredit/contracts+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7610>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Wild Credit, WILD.
# Request error fetching issues for hyle-team/zano: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:hyle-team/zano+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7590>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Zano, ZANO.
# Request error fetching issues for Access-Labs-Inc/accessprotocol.co: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Access-Labs-Inc/accessprotocol.co+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C5B10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Access Protocol, ACS.
# Request error fetching issues for bitfreecash/bitfree: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:bitfreecash/bitfree+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C6550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Bitcoin Free Cash, BFC.
# Request error fetching issues for paxosglobal/busd-contract: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:paxosglobal/busd-contract+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C6F10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: BUSD, BUSD.
# Request error fetching issues for cobak-dev/token-profile: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:cobak-dev/token-profile+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7710>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Cobak Token, CBK.
# Request error fetching issues for Crypto-Energy-Token/CryptoEnergyToken: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Crypto-Energy-Token/CryptoEnergyToken+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7A50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Crypto Energy Token, CET.
# Request error fetching issues for pellartech/vuca-blockchain-public: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:pellartech/vuca-blockchain-public+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7B10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Crown Token, CROWN.
# Request error fetching issues for DioneProtocol/Dione: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:DioneProtocol/Dione+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C4090>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Dione Protocol, DIONE.
# Request error fetching issues for SetProtocol/set-v2: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:SetProtocol/set-v2+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C6F50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: DeFi Pulse Index, DPI.
# Request error fetching issues for techcoincommunity/firecoin: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:techcoincommunity/firecoin+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C4D10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Firecoin, FIRE.
# Request error fetching issues for SafeGem/safegem-finance: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:SafeGem/safegem-finance+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78E1110>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# ...
# Processing coin: XTRA Token, XTRA.
# Request error fetching issues for RevDevPat/Kyuubi: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:RevDevPat/Kyuubi+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7890A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Kyuubi, $KYUB.
# Request error fetching issues for BABYOKX/BABYOKX: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:BABYOKX/BABYOKX+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7891550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: BABYOKX, BABYOKX.
# Request error fetching issues for broxus/octusbridge-contracts: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:broxus/octusbridge-contracts+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7891850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Octus Bridge, BRIDGE.
# Request error fetching issues for sumner770/GalaxyHeroesCoin: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:sumner770/GalaxyHeroesCoin+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892D10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Galaxy Heroes, GHC.
# Request error fetching issues for sumner770/GalaxyHeroesCoin: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:sumner770/GalaxyHeroesCoin+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7893610>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Galaxy Heroes Coin (old), GHC.
# Request error fetching issues for supaafrikan/jolofcoin: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:supaafrikan/jolofcoin+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Jolofcoin, JOL.
# Request error fetching issues for KalissaIO/KALICHAIN: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:KalissaIO/KALICHAIN+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7893810>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: KALICHAIN, KALIS.
# Request error fetching issues for KalissaIO/Kalissa: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:KalissaIO/Kalissa+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7893250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Kalichain, KALIS.
# Request error fetching issues for LendFlare/lendflare_finance_contracts: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:LendFlare/lendflare_finance_contracts+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7891F50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Lend Flare, LFT.
# Request error fetching issues for banklife-io/BankLife?files=1: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:banklife-io/BankLife?files=1+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7891F50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Banklife, LIB.
# Request error fetching issues for Obsidium-cc/Smart-Contract: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Obsidium-cc/Smart-Contract+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892750>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Obsidium, OBS.
# Request error fetching issues for protocolxio/code: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:protocolxio/code+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: ProtocolX, PTX.
# Request error fetching issues for SpaceVikings/SpaceVikings: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:SpaceVikings/SpaceVikings+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7891990>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Space Vikings, SVT.
# Request error fetching issues for TATACoinOfficial/Smart-Contract: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:TATACoinOfficial/Smart-Contract+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78925D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: TATA Coin, TATA.
# Request error fetching issues for timihealth/timicoin: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:timihealth/timicoin+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78937D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Timicoin, TMC.
# Request error fetching issues for Universe-Island/UIM-token: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Universe-Island/UIM-token+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A76C0090>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: UNIVERSE ISLAND, UIM.
# Request error fetching issues for vetherasset/vader-protocol-v2: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:vetherasset/vader-protocol-v2+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Vader Protocol, VADER.
# Request error fetching issues for HawkTahir1/ZENC: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:HawkTahir1/ZENC+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Zenc Coin, ZENC.
# Request error fetching issues for ZatProject/Contract: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:ZatProject/Contract+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7856F10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: ZAT Project, ZPRO.
# Request error fetching issues for ditto-research/ditto-interface: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:ditto-research/ditto-interface+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7893310>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Ditto Staked Aptos, stAPT.
# Request error fetching issues for Stride-Labs/stride: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Stride-Labs/stride+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7855290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Stride Staked EVMOS, stEVMOS.
# Request error fetching issues for Stride-Labs/stride: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Stride-Labs/stride+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78920D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Stride Staked Inj, stINJ.
# Request error fetching issues for Stride-Labs/stride: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Stride-Labs/stride+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78559D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Stride Staked JUNO, stJUNO.
# Request error fetching issues for Narwallets/meta-pool: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Narwallets/meta-pool+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Staked NEAR, STNEAR.
# Request error fetching issues for Stride-Labs/stride: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Stride-Labs/stride+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7891850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Stride Staked SOMM, stSOMM.
# Request error fetching issues for Stride-Labs/stride: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:Stride-Labs/stride+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78562D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Stride Staked UMEE, stUMEE.
# Request error fetching issues for wemixarchive/stWemix-contract: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:wemixarchive/stWemix-contract+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Staked WEMIX, stWEMIX.
# Request error fetching issues for keep-network/tbtc-v2: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:keep-network/tbtc-v2+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A704FD90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: tBTC, TBTC.
# Request error fetching issues for TeleportDAO/teleswap-contracts: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:TeleportDAO/teleswap-contracts+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892E90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: teleBTC, TELEBTC.
# Request error fetching issues for ContractChecker/audits: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:ContractChecker/audits+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A77DB650>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Wrapped Alvey Chain, WALV.
# Request error fetching issues for WrappedBTC/bitcoin-token-smart-contracts: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:WrappedBTC/bitcoin-token-smart-contracts+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A7892E90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Wrapped Dogecoin, WDOGE.
# Request error fetching issues for klaytn/klaytn: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:klaytn/klaytn+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A5C2CF90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Wrapped Klaytn, WKLAY.
# Request error fetching issues for neonlabsorg/neon-evm: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:neonlabsorg/neon-evm+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7650>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Wrapped Neon EVM, WNEON.
# Request error fetching issues for harmony-one/harmony: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:harmony-one/harmony+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C62D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Wrapped Harmony, WONE.
# Request error fetching issues for oasisprotocol/oasis-core: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:oasisprotocol/oasis-core+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C5050>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Wrapped Rose, wROSE.
# Request error fetching issues for thetatoken/theta-protocol-ledger: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:thetatoken/theta-protocol-ledger+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C73D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Wrapped TFUEL, WTFUEL.
# Request error fetching issues for orgs/yieldnest: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /search/issues?q=repo:orgs/yieldnest+type:issue+state:open (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000272A78C7710>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Processing coin: Yieldnest Restaked BNB, ynBNB.
# Filtered repositories saved to 'filtered_repositories_over_200_issues.csv'.
# Total repositories with more than 200 issues: 32

# %%
# read the csv and group by owner/repo to see if the same repo is listed multiple times
import pandas as pd
df = pd.read_csv('filtered_repositories_over_200_issues.csv')
grouped = df.groupby(['owner', 'repo']).size().reset_index(name='count')
duplicates = grouped[grouped['count'] > 1]
print(duplicates)
# Out:
#              owner           repo  count
# 26        celo-org  celo-monorepo      2
# 30        ethereum    go-ethereum      2
# 47   oasisprotocol     oasis-core      2
# 53      paritytech   polkadot-sdk      2
# 63         steemit          steem      2
# 67  ton-blockchain           TEPs      2
# 69     trustwallet         assets      2

# %%
import pandas as pd
import requests
import os
import time

# Read your CSV data
df = pd.read_csv('filtered_repositories_over_200_issues.csv')

# Set your CoinMarketCap API key
api_key = os.getenv('MARKET_CAP_API_KEY')

# Function to get CoinMarketCap data (market cap or market rank) with retry mechanism
def get_market_cap_data(coin_symbol):
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/map'
    params = {
        'symbol': coin_symbol,  # Use the coin symbol to search for it
        'limit': 1,  # Limit to 1 result (we only care about the top result)
    }
    headers = {
        'X-CMC_PRO_API_KEY': api_key,
        'Accept': 'application/json'
    }
    
    max_retries = 5
    backoff_time = 10  # Initial backoff time in seconds

    for attempt in range(max_retries):
        response = requests.get(url, params=params, headers=headers)

        if response.status_code == 200:
            data = response.json()
            if data.get('data'):
                print(f"Coin: {coin_symbol}, Market Cap: {data['data'][0]['rank']}")
                return data['data'][0]['rank']  # Or 'cmc_rank' for market rank
            else:
                print(f"Coin: {coin_symbol}, Market Cap: Not found.")
                return None
        elif response.status_code == 429:
            print(f"Rate limit hit. Retrying in {backoff_time} seconds...")
            time.sleep(backoff_time)
            backoff_time *= 2  # Exponential backoff
        else:
            print(f"Error for coin {coin_symbol}: {response.status_code}")
            break  # Exit the loop for non-retryable errors
    
    return None

# Adding the market cap data to the DataFrame
df['market_cap'] = df['symbol'].apply(get_market_cap_data)

# Filter out rows where market_cap is None (in case the coin wasn't found on CoinMarketCap)
df = df[df['market_cap'].notna()]

# Sort by market cap (descending) and total_issues (descending)
df_sorted = df.sort_values(by=['market_cap', 'total_issues'], ascending=[False, False])

# Drop duplicates and keep the best-ranked coin for each 'owner/repo'
unique_repositories = df_sorted.drop_duplicates(['owner', 'repo'])

# Save the filtered repositories to a new CSV file
unique_repositories.to_csv('filtered_repositories_over_200_issues_unique.csv', index=False)

# Print confirmation message and the count of unique repositories
print(f"Unique repositories saved to 'filtered_repositories_over_200_issues_unique.csv'.")
print(f"Total unique repositories with more than 200 issues: {len(unique_repositories)}")
# Out:
# Coin: AR, Market Cap: 70
# Coin: AVAX, Market Cap: 10
# Coin: BEAM, Market Cap: 83
# Coin: BSV, Market Cap: 72
# Coin: BTC, Market Cap: 1
# Coin: DOGE, Market Cap: 7
# Coin: DOT, Market Cap: 15
# Coin: EOS, Market Cap: 81
# Coin: ETC, Market Cap: 28
# Coin: ETH, Market Cap: 2
# Coin: LINK, Market Cap: 16
# Coin: LTC, Market Cap: 23
# Coin: NEO, Market Cap: 91
# Coin: TAO, Market Cap: 32
# Coin: TRX, Market Cap: 11
# Coin: XLM, Market Cap: 14
# Coin: XMR, Market Cap: 51
# Coin: ASTR, Market Cap: 136
# Coin: BAT, Market Cap: 168
# Coin: BTG, Market Cap: 132
# Coin: CELO, Market Cap: 162
# Coin: DASH, Market Cap: 169
# Coin: HOT, Market Cap: 153
# Coin: IOTX, Market Cap: 170
# Coin: KSM, Market Cap: 138
# Coin: MASK, Market Cap: 196
# Coin: MASK, Market Cap: 196
# Coin: MINA, Market Cap: 101
# Coin: OSMO, Market Cap: 180
# Coin: QTUM, Market Cap: 182
# Rate limit hit. Retrying in 10 seconds...
# Rate limit hit. Retrying in 20 seconds...
# Rate limit hit. Retrying in 40 seconds...
# Coin: ROSE, Market Cap: 123
# Coin: RVN, Market Cap: 193
# Coin: TRAC, Market Cap: 178
# Coin: W, Market Cap: 114
# Coin: ZEC, Market Cap: 103
# Coin: ZIL, Market Cap: 159
# Coin: BLAST, Market Cap: 252
# Coin: MPLX, Market Cap: 251
# Coin: SSV, Market Cap: 200
# Coin: STORJ, Market Cap: 276
# Coin: XCH, Market Cap: 230
# Coin: DAG, Market Cap: 271
# Coin: LQTY, Market Cap: 355
# Coin: SCRT, Market Cap: 325
# Coin: ACE, Market Cap: 420
# Coin: COW, Market Cap: 434
# Coin: MOB, Market Cap: 536
# Coin: STEEM, Market Cap: 407
# Coin: SYS, Market Cap: 455
# Coin: ZANO, Market Cap: 490
# Coin: INSURANCE, Market Cap: 595
# Coin: OMG, Market Cap: 608
# Coin: SBD, Market Cap: 643
# Coin: PIVX, Market Cap: 890
# Coin: CHAT, Market Cap: 1078
# Coin: DFI, Market Cap: 1084
# Coin: KLIMA, Market Cap: 1154
# Coin: PPC, Market Cap: 1123
# Coin: OGV, Market Cap: 1206
# Coin: CEUR, Market Cap: 1457
# Coin: STC, Market Cap: 1201
# Coin: SPARTA, Market Cap: 2085
# Coin: GLINT, Market Cap: 2199
# Coin: VEIL, Market Cap: 2236
# Coin: KING, Market Cap: 2362
# Coin: RED, Market Cap: 2722
# Coin: AIN, Market Cap: 3702
# Coin: MAS, Market Cap: 3540
# Coin: IST, Market Cap: 4187
# Coin: LAOS, Market Cap: 6427
# Coin: CATS, Market Cap: 2913
# Coin: BBC, Market Cap: 3700
# Coin: NU, Market Cap: 5587
# Coin: WIT, Market Cap: 4549
# Coin: HMX, Market Cap: 4474
# Coin: MMT, Market Cap: 5078
# Coin: PARA, Market Cap: 7677
# Coin: WKLAY, Market Cap: 10173
# Coin: WONE, Market Cap: 10167
# Coin: wROSE, Market Cap: 10182
# Unique repositories saved to 'filtered_repositories_over_200_issues_unique.csv'.
# Total unique repositories with more than 200 issues: 73

# %%
if(len(df)-len(unique_repositories) == len(duplicates)):
    print("The number of duplicates matches the difference between the original and unique repositories.")
else:
    print("The number of duplicates does not match the difference between the original and unique repositories.")
# Out:
# The number of duplicates matches the difference between the original and unique repositories.
